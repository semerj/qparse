# %%
import os
from pprint import pprint
import xmltodict

# %%
path = 'stanford-corenlp-full-2014-08-27/xmlout/'
xmlfiles = [path+filename for filename in os.listdir(path) if filename.endswith('.xml')]
txtpath = 'stanford-corenlp-full-2014-08-27/articles/'
txtfiles = [txtpath+filename for filename in os.listdir(txtpath) if not filename.startswith('all-articles') and filename.endswith('.txt')]
txtout = 'stanford-corenlp-full-2014-08-27/txtout/'
outfiles = [txtout+filename for filename in os.listdir(txtpath) if not filename.startswith('all-articles') and filename.endswith('.txt')]

# %%
for fileindex, filepath in enumerate(xmlfiles): 
    with open(filepath, 'r') as xmlfile: 
        filedict = xmltodict.parse(xmlfile.read())
        
    # make sure it's a list, if there's only one coref
    corefs =  filedict['root']['document']['coreference']['coreference']
#     ner = filedict['root']['document']['sentences']['sentence'][0]['tokens']['token'][0] # coref index - 1
    sentences = filedict['root']['document']['sentences']['sentence']

    # extract a list of persons and their indices in each sentence
    names = set()
    person_locs = []
    for sentence in sentences: 
        tokens = sentence['tokens']['token']
        # aggregate adjacent NER person tags into full names
        i = 0
        people = {}
        while i < len(tokens):
            if tokens[i]['NER'] == 'PERSON':
                key = i
                person = tokens[i]['word']
                # keep adding to this person string while the next token is also a person
                i += 1
                while tokens[i]['NER'] == 'PERSON':
                    person += ' ' + tokens[i]['word']
                    i += 1
                people[key] = person
                names.add(person)
            i += 1
        person_locs.append(people)

    # sometimes it misses last name references to the same person - can we merge them?
    # do another pass on person_locs to clean up names
    names_to_replace = {}
    for name in names: 
        other_names = {n for n in names if n != name}
        # NOTE: this is a naive algorithm, it just picks the first match
        # even though multiple people may have the same last name
        for n in other_names: 
            if n in name:
                names_to_replace[n] = name
    for sent in person_locs:
        for loc in sent:
            if sent[loc] in names_to_replace:
                sent[loc] = names_to_replace[sent[loc]]
    
    # assemble NERs that correspond to each coref chain
    corefs_text = {}
    corefs_ends = {}
    for coref_chain in corefs:
        indices = {}
        ends = {}
        # weird stuff happens if there's only one coref chain in an article, so back up one level
        if coref_chain == "mention":
            coref_chain = corefs
        
        for mention in coref_chain['mention']:
            sent_index = int(mention['sentence']) - 1
            word_start = int(mention['start']) - 1
            word_end = int(mention['end']) - 1
            if word_start in person_locs[sent_index]:
                # does anything in this chain match an NER person?
                # IF SO, store whole coref chain,
                # but only the names and sentence/word indices
                sent_indices = list({int(m['sentence'])-1 for m in coref_chain['mention']})
                for sent in sent_indices: 
                    if sent not in indices:
                        indices[sent] = {}
                        ends[sent] = {}
                    # add words
                    words_in_sent = {int(m['start'])-1: '' 
                                     for m in coref_chain['mention'] 
                                     if m['sentence'] == str(sent+1)}
                    indices[sent].update(words_in_sent)
                    # add endings
                    ends_in_sent = {int(m['start'])-1: int(m['end'])-1 
                                    for m in coref_chain['mention'] 
                                    if m['sentence'] == str(sent+1)}
                    ends[sent].update(ends_in_sent)
                break
                
        if indices:
            # get all NER person hits in the chain
            # TODO: what if they don't match exactly (eg, coref only catches the last name?)
            ners = []
            for sent_index in indices: 
                for word in indices[sent_index]:
                    if word in person_locs[sent_index]:
                        ners.append(person_locs[sent_index][word])    
            # canonical name is the longest one, not necessarily the first
            name = "{{" + max(ners, key=len) + "}}"  
            # braces just to make clear this was replaced by the program
            
            # replace matched indices with name in corefs_text
            for sent_index in indices:
                if sent_index not in corefs_text:
                    corefs_text[sent_index] = {}
                    corefs_ends[sent_index] = {}
                for word in indices[sent_index]:
                    corefs_text[sent_index][word] = name
                    corefs_ends[sent_index].update(ends[sent_index])
                
    # get original text, and replace corefs with canonical names
    with open(txtfiles[fileindex], 'r') as infile:
        article = infile.read()
    
    # go in reverse order so the offsets don't cascade
    sents_to_replace = sorted(corefs_text.keys())
    sents_to_replace.reverse()
    for i in sents_to_replace:
        # look up the character offsets for each word
        sentence = filedict['root']['document']['sentences']['sentence'][i]
        tokens = sentence['tokens']['token']
        locs = sorted(corefs_text[i].keys())
        locs.reverse()
        splice = [(int(tokens[loc]['CharacterOffsetBegin']), int(tokens[corefs_ends[i][loc]-1]['CharacterOffsetEnd']))
                      for loc in locs]
        
        # account for overlapping coreferences
        for index, block in enumerate(splice):
            if index + 1 < len(splice):
                # detect an overlap in character ranges and keep the one that starts first
                if block[0] < splice[index + 1][1]:
                    splice[index] = None

        for index,loc in enumerate(locs):
            # if splice is None, skip it
            if splice[index]:
                article = article[:splice[index][0]] + corefs_text[i][loc] + article[splice[index][1]:]

#     print article
#     print "-" * 30
    
    with open(outfiles[fileindex], 'w') as outfile:
        outfile.write(article)
# Out:
# NAIROBI, Kenya (AP) _ Thousands of laborers, students and opposition politicians on Saturday protested tax hikes imposed by their cash-strapped government, which they accused of failing to provide basic services. Beneath a scorching sun, they sang anti-government songs and chanted "{{Daniel arap Moi}} must go," showing their derision for {{Daniel arap Moi}}, {{Daniel arap Moi}}. By voice vote, the 5,000 protesters approved a resolution calling for the government to scrap new taxes, convene a convention to write a new Constitution, stop harassing students and street vendors, and halt ethnic violence. If the government doesn't respond to the demands, workers should go on strike April 3, said Kivutha Kibwana, of the National Convention Assembly, a group of opposition political, church and civic leaders who organized the rally. Although the crowd cheered its support, the assembly's calls for general strikes have failed in the past. Kenyans are most angered by tax increases announced earlier this month to plug a widening budget deficit. The price of gas and diesel went up, and tax deductions were revoked on gifts to charities and nonprofit organizations. Faced with a strike by bank workers, Finance Minister Simeon Nyachae delayed plans to raise taxes on cut-rate loans provided by employers. Several politicians have charged that the high taxes Kenyans already pay go into the pockets of government officials or wasteful projects, and not into providing essential services and repairing crumbling infrastructure. "{{Kenneth Matiba}} would like {{Daniel arap Moi}} to explain and bring back the money {{Daniel arap Moi}} has stolen," said {{Kenneth Matiba}}. The International Monetary Fund has demanded spending cuts and tax hikes, warning that in the absence of corrective measures, Kenya's overall budget deficit for 1997 - 98 will reach 3.9 percent of the gross domestic product _ more than double the goal of 1.7 percent. The IMF last year withheld a dlrs 220 million loan from Kenya, citing official corruption and mismanagement. In contrast to other rallies which have drawn mostly male students, Saturday's rally also attracted laborers, businessmen and women. They demonstrated at the Kamukunji Grounds, a grassy field in Nairobi where Kenyans have often gathered to show their dissatisfaction with the government. "We, the people of Kenya, have met here several times. We have been beaten, we have shed blood, we have purchased the right to meet here today with our blood," said {{John Munuve}}, {{John Munuve}}. The protest was peaceful, and no police were deployed. In July, police killed more than a dozen demonstrators pressing for constitutional reforms before elections in December, in which {{Daniel arap Moi}} won a fifth, five-year term. (cm-kjd)
yn A. Walker}}. {{Olowe}} gained attention in Europe when an elaborate palace door {{Roslyn A. Walker}} had made was displayed in the British Empire Exhibition of 1927 and later acquired by the British Museum. After World War II, an English official saw a picture of the door and related its distinctive style to work he had encountered in Nigeria. He alerted the ethnographer William B. Fagg to his discovery, thus setting in motion the investigation that has culminated in {{Roslyn A. Walker}} show. The British Museum door is not in Washington for the exhibition, which runs through Sept. 7, but two others by {{Olowe}} are, each carved with reliefs of dozens of figures arranged in horizontal bands. The first door depicts the everyday bustle of court life: the ruler, short but commanding, appears accompanied by two wives, one wearing a European-style top hat. A band of eager-to-please musicians serenades him from above; a wrestling match is in progress below. The other door documents a specific event: the turn-of-the-century meeting between a British commissio ...
# ------------------------------

# %%
import nltk

# %%
# compare NLTK NER tool to Stanford output
nltk.ne_chunk
for fileindex, filepath in enumerate(xmlfiles): 
    with open(filepath, 'r') as xmlfile: 
        filedict = xmltodict.parse(xmlfile.read())
        
    sentences = filedict['root']['document']['sentences']['sentence']
    tagged_sentences = []
    # construct tagged token list for nltk input
    for sentence in sentences: 
        tagged_sentence = []
        tokens = sentence['tokens']['token']
        print 'StanfordNLP NER:'
        for token in tokens: 
            tagged_sentence.append((token['word'], token['POS']))
            if token['NER'] == 'PERSON':
                print token['word']
        print ' '
        print 'NLTK NER:'
        ner = nltk.ne_chunk(tagged_sentence)
        for subtree in ner.subtrees():
            if subtree.node == 'PERSON':
                print subtree
        # tagged_sentences.append(tagged_sentence)
        print '-' * 30
        print ' '
# Stanford seems to be better, at least out of the box
# Out:
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Kenya/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Moi
# Daniel
# arap
# Moi
#
# NLTK NER:
# (PERSON Daniel/NNP)
# (PERSON Kenya/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kivutha
# Kibwana
#
# NLTK NER:
# (PERSON Kivutha/NNP Kibwana/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Simeon
# Nyachae
#
# NLTK NER:
# (PERSON Simeon/NNP Nyachae/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Moi
# Kenneth
# Matiba
# Moi
#
# NLTK NER:
# (PERSON Moi/NNP)
# (PERSON Kenneth/NNP Matiba/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Kenya/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# John
# Munuve
#
# NLTK NER:
# (PERSON John/NNP Munuve/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Moi
#
# NLTK NER:
# (PERSON Moi/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Alexey
# Prokurorov
#
# NLTK NER:
# (PERSON Alexey/NNP Prokurorov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Odd
# Bjorn
# Hjelmeseth
# Bjorn
# Dahlie
# Anders
# Aukland
# Erling
# Jevne
#
# NLTK NER:
# (PERSON Odd/NNP Bjorn/NNP Hjelmeseth/NNP)
# (PERSON Bjorn/NNP Dahlie/NNP)
# (PERSON Anders/NNP Aukland/NNP)
# (PERSON Jevne/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Prokurorov
#
# NLTK NER:
# (PERSON Prokurorov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Thomas
# Alsgaard
#
# NLTK NER:
# (PERSON Thomas/NNP Alsgaard/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dahlie
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dahlie
#
# NLTK NER:
# (PERSON Dahlie/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Larissa
# Lazutina
# Svetlana
# Nageykina
#
# NLTK NER:
# (PERSON Larissa/NNP Lazutina/NNP)
# (PERSON Svetlana/NNP Nageykina/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Lazutina
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Anita
# Moen-Guidon
# Lazutina
# Julia
# Chepalova
#
# NLTK NER:
# (PERSON Anita/NNP)
# (PERSON Julia/NNP Chepalova/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Bente
# Martinsen
#
# NLTK NER:
# (PERSON Bente/NNP Martinsen/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Stefania
# Belmondo
#
# NLTK NER:
# (PERSON Stefania/NNP Belmondo/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Paul
# VI
#
# NLTK NER:
# (PERSON Paul/NNP VI/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Jesus
#
# NLTK NER:
# (PERSON Nostra/NNP Aetate/NNP)
# ------------------------------
#
# StanfordNLP NER:
# John
# Paul
# II
#
# NLTK NER:
# (PERSON Pope/NNP)
# (PERSON John/NNP Paul/NNP II/NNP)
# (PERSON Jews/NNPS)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Jews/NNPS)
# ------------------------------
#
# StanfordNLP NER:
# Kurt
# Waldheim
#
# NLTK NER:
# (PERSON Kurt/NNP Waldheim/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# John
# Paul
#
# NLTK NER:
# (PERSON John/NNP Paul/NNP)
# (PERSON Jews/NNPS)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# pope
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Christian
# Lacroix
#
# NLTK NER:
# (PERSON Christian/JJ Lacroix/NNP)
# (PERSON Carrousel/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Belle/NNP Epoque/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Christian
# Lacroix
#
# NLTK NER:
# (PERSON Christian/JJ Lacroix/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Jean-Jacques
# Picart
# Lacroix
# Louis
# Vuitton
# Moet
# Hennesy
#
# NLTK NER:
# (PERSON Jean-Jacques/NNP Picart/NNP)
# (PERSON Lacroix/NNP)
# (PERSON Louis/NNP Vuitton/NNP Moet/NNP Hennesy/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Lacroix
#
# NLTK NER:
# (PERSON Lacroix/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Lacroix
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Scarlet
# O'Hara
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Jean-Paul
# Gaultier
#
# NLTK NER:
# (PERSON Jean-Paul/NNP Gaultier/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Naomi
# Campbell
# Nanook
#
# NLTK NER:
# (PERSON Naomi/NNP Campbell/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Colin
# McDowell
#
# NLTK NER:
# (PERSON Colin/NNP McDowell/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Gunda
# Niemann
# Claudia
# Pechstein
#
# NLTK NER:
# (PERSON Gunda/NNP Niemann/NNP)
# (PERSON German/JJ Claudia/NNP Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Niemann
#
# NLTK NER:
# (PERSON Niemann/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Pechstein
# Niemann
#
# NLTK NER:
# (PERSON Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Gunda
# Niemann
# Claudia
# Pechstein
#
# NLTK NER:
# (PERSON Gunda/NNP Niemann/NNP)
# (PERSON German/JJ Claudia/NNP Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Niemann
#
# NLTK NER:
# (PERSON Niemann/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Pechstein
# Niemann
#
# NLTK NER:
# (PERSON Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Alexey
# Prokurorov
#
# NLTK NER:
# (PERSON Alexey/NNP Prokurorov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Odd
# Bjorn
# Hjelmeseth
# Bjorn
# Dahlie
# Anders
# Aukland
# Erling
# Jevne
#
# NLTK NER:
# (PERSON Odd/NNP Bjorn/NNP Hjelmeseth/NNP)
# (PERSON Bjorn/NNP Dahlie/NNP)
# (PERSON Anders/NNP Aukland/NNP)
# (PERSON Jevne/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Prokurorov
#
# NLTK NER:
# (PERSON Prokurorov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Thomas
# Alsgaard
#
# NLTK NER:
# (PERSON Thomas/NNP Alsgaard/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dahlie
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dahlie
#
# NLTK NER:
# (PERSON Dahlie/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Larissa
# Lazutina
# Svetlana
# Nageykina
#
# NLTK NER:
# (PERSON Larissa/NNP Lazutina/NNP)
# (PERSON Svetlana/NNP Nageykina/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Lazutina
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Anita
# Moen-Guidon
# Lazutina
# Julia
# Chepalova
#
# NLTK NER:
# (PERSON Anita/NNP)
# (PERSON Julia/NNP Chepalova/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Bente
# Martinsen
#
# NLTK NER:
# (PERSON Bente/NNP Martinsen/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Stefania
# Belmondo
#
# NLTK NER:
# (PERSON Stefania/NNP Belmondo/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Firoz
# Ali
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ali
# Rick
# Todd
#
# NLTK NER:
# (PERSON Ali/NNP)
# (PERSON Rick/NNP Todd/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Ali
# Dean
# Wilson
# Tim
# Straub
# Scott
# Rowe
#
# NLTK NER:
# (PERSON Ali/NNP)
# (PERSON Dean/NNP Wilson/NNP)
# (PERSON Tim/NNP Straub/NNP)
# (PERSON Scott/NNP Rowe/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Firoz
# Dean
#
# NLTK NER:
# (PERSON Firoz/NNP)
# (PERSON Dean/NNP)
# ------------------------------
#
# StanfordNLP NER:
# David
# Prinosil
# Jan
# Siemerink
#
# NLTK NER:
# (PERSON Denmark/NNP)
# (PERSON David/NNP Prinosil/NNP)
# (PERSON Jan/NNP Siemerink/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Magnus
# Gustafsson
# Kenneth
# Carlsen
#
# NLTK NER:
# (PERSON Magnus/NNP Gustafsson/NNP)
# (PERSON Kenneth/NNP Carlsen/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Prinosil
#
# NLTK NER:
# (PERSON Siemerink/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Thomas
# Johansson
#
# NLTK NER:
# (PERSON German/NNP)
# (PERSON Thomas/NNP Johansson/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Prinosil
#
# NLTK NER:
# (PERSON Prinosil/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Anatoly
# Ponidelko
#
# NLTK NER:
# (PERSON Anatoly/NNP Ponidelko/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Hamas/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Gunda
# Niemann
# Claudia
# Pechstein
#
# NLTK NER:
# (PERSON Gunda/NNP Niemann/NNP)
# (PERSON German/JJ Claudia/NNP Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Niemann
#
# NLTK NER:
# (PERSON Niemann/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Pechstein
# Niemann
#
# NLTK NER:
# (PERSON Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Anni
# Friesinger
#
# NLTK NER:
# (PERSON Anni/NNP Friesinger/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Niemann
#
# NLTK NER:
# (PERSON Niemann/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Ids
# Postma
#
# NLTK NER:
# (PERSON Rintje/NNP Ritsma/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Postma
#
# NLTK NER:
# (PERSON Postma/NNP)
# (PERSON Ritsma/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Postma
#
# NLTK NER:
# (PERSON Postma/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ritsma
#
# NLTK NER:
# (PERSON Ritsma/NNP)
# ------------------------------
# StanfordNLP NER:
# Ritsma
#
# NLTK NER:
# (PERSON Ritsma/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Postma
# Ritsma
#
# NLTK NER:
# (PERSON Postma/NNP)
# (PERSON Ritsma/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Roberto
# Sighel
#
# NLTK NER:
# (PERSON Roberto/NNP Sighel/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Niemann
# Pechstein
#
# NLTK NER:
# (PERSON Niemann/NNP)
# (PERSON Pechstein/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Chris
# Witty
#
# NLTK NER:
# (PERSON Chris/NNP Witty/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Boban
# Boskovic
# Ilinka
# Durbaba
#
# NLTK NER:
# (PERSON Boban/NNP Boskovic/NNP)
# (PERSON Ilinka/NN Durbaba/NN)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/JJ)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Milica
# Boskovic
#
# NLTK NER:
# (PERSON Milica/NNP Boskovic/NNP)
# (PERSON Albanian/JJ)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanians/NNS)
# ------------------------------
#
# StanfordNLP NER:
# Boskovic
#
# NLTK NER:
# (PERSON Boskovic/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Boban
# Boskovic
# Albanian
#
# NLTK NER:
# (PERSON Boban/NNP Boskovic/NNP)
# (PERSON Albanian/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/JJ)
# ------------------------------
#
# StanfordNLP NER:
# Boskovic
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Milosevic
# Rugova
# Boskovic
# Albanian
#
# NLTK NER:
# (PERSON Milosevic/NNP)
# (PERSON Boskovic/NNP)
# (PERSON Albanian/JJ)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Boskovic
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Zeljko
# Raznatovic
# Arkan
#
# NLTK NER:
# (PERSON Zeljko/NNP Raznatovic/NNP)
# (PERSON Arkan/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Tito
#
# NLTK NER:
# (PERSON Tito/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/JJ)
# (PERSON Albania/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Zhivka
# Savic
#
# NLTK NER:
# (PERSON Zhivka/NNP Savic/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Savic
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/JJ)
# ------------------------------
#
# StanfordNLP NER:
# Milanka
# Milentijevic
#
# NLTK NER:
# (PERSON Milanka/NNP Milentijevic/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Milentijevic
#
# NLTK NER:
# (PERSON Milentijevic/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Albanian/JJ)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Milentijevic
#
# NLTK NER:
# (PERSON Milentijevic/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Durbaba
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Croats/NNPS)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Slobodan
# Milosevic
#
# NLTK NER:
# (PERSON Slobodan/NNP Milosevic/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Knin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Durbaba
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Mark
# Litton
#
# NLTK NER:
# (PERSON Kenya/NNP)
# (PERSON Mark/NNP Litton/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Litton/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Jacob
# Okello
# Ricardo
# Gonzalez
#
# NLTK NER:
# (PERSON Kenyan/JJ Jacob/NNP Okello/NNP)
# (PERSON Argentine/JJ Ricardo/NNP Gonzalez/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Litton/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Okello
#
# NLTK NER:
# (PERSON Okello/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Okello
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# John
# Mellor
#
# NLTK NER:
# (PERSON John/NNP Mellor/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Seve
# Ballesteros
# Jose
# Maria
# Canizares
# Ian
# Woosnam
#
# NLTK NER:
# (PERSON Seve/NNP Ballesteros/NNP)
# (PERSON Jose/NNP Maria/NNP Canizares/NNP)
# (PERSON Ian/NNP Woosnam/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Guyana/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Guyana/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Satydeo
# Sawh
#
# NLTK NER:
# (PERSON Satydeo/NNP Sawh/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Judaism/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Paul
# VI
#
# NLTK NER:
# (PERSON Paul/NNP VI/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Jesus
#
# NLTK NER:
# (PERSON Nostra/NNP Aetate/NNP)
# ------------------------------
#
# StanfordNLP NER:
# John
# Paul
# II
#
# NLTK NER:
# (PERSON Pope/NNP)
# (PERSON John/NNP Paul/NNP II/NNP)
# (PERSON Jews/NNPS)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Jews/NNPS)
# ------------------------------
#
# StanfordNLP NER:
# Kurt
# Waldheim
#
# NLTK NER:
# (PERSON Kurt/NNP Waldheim/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# John
# Paul
#
# NLTK NER:
# (PERSON John/NNP Paul/NNP)
# (PERSON Jews/NNPS)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# pope
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Party/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Chen
# Jin
#
# NLTK NER:
# (PERSON Chen/NNP Jin/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Fu
# Shenqi
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Aldo
# Moro
#
# NLTK NER:
# (PERSON Aldo/NNP Moro/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Moro/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Moro/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Giulio
# Andreotti
#
# NLTK NER:
# (PERSON Giulio/NNP Andreotti/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Andreotti
#
# NLTK NER:
# (PERSON Andreotti/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Moro
#
# NLTK NER:
# (PERSON Moro/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Mario
# Moretti
#
# NLTK NER:
# (PERSON Mario/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Vita
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Anna
# Braghetti
# Moro
#
# NLTK NER:
# (PERSON Anna/NNP Braghetti/NNP)
# (PERSON Moro/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Moro
# Braghetti
# Corriere
# della
# Sera
#
# NLTK NER:
# (PERSON Moro/NNP)
# (PERSON Braghetti/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Hamas/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Eduard
# Shevardnadze
# Mesut
# Yilmaz
#
# NLTK NER:
# (PERSON Georgian/JJ)
# (PERSON Eduard/NNP Shevardnadze/NNP)
# (PERSON Mesut/NNP Yilmaz/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Baku/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Azerbaijan/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Georgia/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Mick
# North
# Sophie
#
# NLTK NER:
# (PERSON Mick/NNP North/NNP)
# (PERSON Sophie/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Thomas
# Hamilton
#
# NLTK NER:
# (PERSON Thomas/NNP Hamilton/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kofi
# Annan
#
# NLTK NER:
# (PERSON Kofi/NNP Annan/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Jerusalem/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Brigades/NNS)
# (PERSON Hardon/NNP)
# (PERSON Hadatha/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Tyre/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Bahia
# Hariri
#
# NLTK NER:
# (PERSON Bahia/NNP Hariri/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Mohammed
# Beydoun
#
# NLTK NER:
# (PERSON Mohammed/NNP Beydoun/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Occupied/NNP Southern/NNP Lebanon/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Eli
# Bin
#
# NLTK NER:
# (PERSON Eli/NNP Bin/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Hamas/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Africa/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kofi
# Annan
#
# NLTK NER:
# (PERSON Kofi/NNP Annan/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Annan
#
# NLTK NER:
# (PERSON Annan/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Annan
#
# NLTK NER:
# (PERSON Annan/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Annan
# Antonio
# Monteiro
#
# NLTK NER:
# (PERSON Annan/NNP)
# (PERSON Antonio/NNP Monteiro/NNP)
# (PERSON Africa/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Monteiro
#
# NLTK NER:
# (PERSON Monteiro/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Hutu
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Zaire/NNP)
# ------------------------------
#
# StanfordNLP NER:
# John
# Weston
#
# NLTK NER:
# (PERSON John/NNP Weston/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Weston
# Clinton
#
# NLTK NER:
# (PERSON Weston/NNP)
# (PERSON Clinton/NNP)
# (PERSON Africa/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Alain
# Dejammet
#
# NLTK NER:
# (PERSON Alain/NNP Dejammet/NNP)
# (PERSON France/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Annan
#
# NLTK NER:
# (PERSON Annan/NNP)
# (PERSON Africa/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Annan
#
# NLTK NER:
# (PERSON Annan/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Wembley/NNP Industries/NNP Holdings/NNP Bhd/NNP)
# (PERSON Jalan/NNP Bukit/NNP Kemuning/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Shah
# Alam
# G.
# Selvakumar
#
# NLTK NER:
# (PERSON Shah/NNP)
# (PERSON Deputy/NNP Superintendent/NNP)
# (PERSON Selvakumar/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Selangor
# Menteri
# Besar
# Datuk
# Abu
# Hassan
# Omar
#
# NLTK NER:
# (PERSON Selangor/NNP)
# (PERSON Menteri/NNP Besar/NNP Datuk/NNP Abu/NNP Hassan/NNP Omar/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Selangor/NNP Malay/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Abu
# Hassan
#
# NLTK NER:
# (PERSON Abu/NNP)
# (PERSON Hassan/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Abu
# Hassan
#
# NLTK NER:
# (PERSON Abu/NNP Hassan/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Datuk
# Hashim
# Meon
#
# NLTK NER:
# (PERSON Datuk/NNP Hashim/NNP Meon/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Club/NNP Med/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Club/NNP Med/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Pahang/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# NLTK NER:
# (PERSON Impiana/NNP)
# (PERSON Residence/NNP Inn/NNP)
# (PERSON Villa/NNP Cherating/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Santhi
# Jayadhan
#
# NLTK NER:
# (PERSON Santhi/NNP Jayadhan/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Santhi
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Abang
#
# NLTK NER:
# (PERSON Rantau/NNP Abang/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Wan
# Yeh
# Mahmood
#
# NLTK NER:
# (PERSON Wan/NNP Yeh/NNP Mahmood/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Pulau/NNP Ular/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Pulau/NNP Ular/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Wan
#
# NLTK NER:
# (PERSON Wan/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kevin
# Loh
#
# NLTK NER:
# (PERSON Kevin/NNP Loh/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Mak
# De
#
# NLTK NER:
# (PERSON Mak/NNP De/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Santhi
#
# NLTK NER:
# (PERSON Mak/NNP Long/NNP De/NNP)
# (PERSON Santhi/NNP)
# (PERSON Club/NNP Med/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Pak
# De
#
# NLTK NER:
# (PERSON Mak/NNP Long/NNP De/NNP)
# (PERSON Pak/NNP De/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Pak
# De
#
# NLTK NER:
# (PERSON Pak/NNP De/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON San/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Bakili
# Muluzi
#
# NLTK NER:
# (PERSON Bakili/NNP Muluzi/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Eric
# Kumitsonyo
# Felix
# Mchamithe
# Muluzi
# Kamuzu
# Banda
#
# NLTK NER:
# (PERSON Blantyre/NNP)
# (PERSON Eric/NNP Kumitsonyo/NNP)
# (PERSON Felix/NNP Mchamithe/NNP)
# (PERSON Muluzi/NNP)
# (PERSON Kamuzu/NNP Banda/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kumitsonyo
#
# NLTK NER:
# (PERSON Kumitsonyo/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kumitsonyo
#
# NLTK NER:
# (PERSON Kumitsonyo/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Mchamithe
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Banda
# Muluzi
#
# NLTK NER:
# (PERSON Banda/NNP)
# (PERSON Muluzi/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
# Banda
# Banda
#
# NLTK NER:
# (PERSON Muluzi/NNP)
# (PERSON Banda/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Banda
# Muluzi
#
# NLTK NER:
# (PERSON Banda/NNP)
# (PERSON Muluzi/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
#
# NLTK NER:
# (PERSON Daily/NNP Times/NNP)
# (PERSON Muluzi/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
#
# NLTK NER:
# (PERSON Muluzi/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Kenya/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Thomas
# Gurtner
#
# NLTK NER:
# (PERSON Swiss/JJ Thomas/NNP Gurtner/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Gurtner
#
# NLTK NER:
# (PERSON Gurtner/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Christoph
# Langenkamp
# Patrick
# Berner
# Markus
# Fasel
# Nadine
# Piantowsky
#
# NLTK NER:
# (PERSON Vandenhove/NN)
# (PERSON German/JJ Christoph/NNP Langenkamp/NNP)
# (PERSON Patrick/NNP Berner/NNP)
# (PERSON Markus/NNP Fasel/NNP)
# (PERSON Nadine/NNP Piantowsky/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Robi
# Byrd
# Steve
# Riungu
#
# NLTK NER:
# (PERSON Kenyan/JJ Steve/NNP Riungu/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Mogadishu/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Somali
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ali
# Mahdi
# Mohamed
#
# NLTK NER:
# (PERSON Ali/NNP Mahdi/NNP Mohamed/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Bill
# Grant
#
# NLTK NER:
# (PERSON Bill/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Mohamed
# Siad
# Barre
#
# NLTK NER:
# (PERSON Mohamed/NNP Siad/NNP Barre/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Gurtner
#
# NLTK NER:
# (PERSON Mogadishu/NNP)
# (PERSON Gurtner/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Hope/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Gurtner
#
# NLTK NER:
# (PERSON Gurtner/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ali
# Mahdi
# Mohamed
#
# NLTK NER:
# (PERSON Ali/NNP)
# (PERSON Mahdi/NNP Mohamed/NNP)
# (PERSON Mogadishu/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Carla
# del
# Ponte
# Yuri
# Skuratov
#
# NLTK NER:
# (PERSON Swiss/NNP Federal/NNP)
# (PERSON Carla/NNP)
# (PERSON Yuri/NNP Skuratov/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Skuratov
# Skuratov
#
# NLTK NER:
# (PERSON Skuratov/NNP)
# (PERSON Skuratov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Skuratov
#
# NLTK NER:
# (PERSON Skuratov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Skuratov
#
# NLTK NER:
# (PERSON Skuratov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# del
# Ponte
#
# NLTK NER:
# (PERSON Ponte/NNP)
# ------------------------------
#
# StanfordNLP NER:
# del
# Ponte
#
# NLTK NER:
# (PERSON Ponte/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Skuratov
#
# NLTK NER:
# (PERSON Skuratov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Del
# Ponte
# Sergei
# Mikhailov
#
# NLTK NER:
# (PERSON Del/NNP)
# (PERSON Ponte/NNP)
# (PERSON Sergei/NNP Mikhailov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Mikhailov
#
# NLTK NER:
# (PERSON Mikhailov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# del
# Ponte
#
# NLTK NER:
# (PERSON Ponte/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Sergei
# Kiriyenko
#
# NLTK NER:
# (PERSON Sergei/NNP Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Water/NNP Transport/NNP Engineering/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
# Nizhny
# Novgorod
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# (PERSON Nizhny/NNP Novgorod/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Gorky
#
# NLTK NER:
# (PERSON Gorky/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Nizhny
# Novgorod
#
# NLTK NER:
# (PERSON Nizhny/NNP Novgorod/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
# Kiriyenko
#
# NLTK NER:
# (PERSON Yeltsin/NN)
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Datuk
# S.
# Subramaniam
#
# NLTK NER:
# (PERSON Subramaniam/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Subramaniam
#
# NLTK NER:
# (PERSON Subramaniam/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Datuk
# Abu
# Zahar
# Ujang
#
# NLTK NER:
# (PERSON Datuk/NNP Abu/NNP Zahar/NNP Ujang/NNP)
# (PERSON Kuala/NNP Pilah/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Tanjung/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Lim
#
# NLTK NER:
# (PERSON Konsortium/NNP Perkapalan/NNP)
# (PERSON Lim/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Lim
#
# NLTK NER:
# (PERSON Lim/NNP)
# (PERSON Ekran/NNP Bhd/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Husni
# Hanadzlah
#
# NLTK NER:
# (PERSON Husni/NNP)
# (PERSON Hanadzlah/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Husni
#
# NLTK NER:
# (PERSON Husni/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Michael
# Lisa
# Kaya
#
# NLTK NER:
# (PERSON Michael/NNP Lisa/NNP Kaya/NNP)
# (PERSON Bukit/NNP Mas/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Sahabat
# Alam
# Malaysia
#
# NLTK NER:
# (PERSON Sahabat/NNP Alam/NNP Malaysia/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Mentakab/NNP)
# (PERSON Kiow/NN)
# ------------------------------
#
# StanfordNLP NER:
# M.
# Kulasegaran
#
# NLTK NER:
# (PERSON Teluk/NNP Intan/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Subramaniam
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Datuk
# Loke
# Yuen
# Yow
#
# NLTK NER:
# (PERSON Deputy/NNP Youth/NNP)
# (PERSON Datuk/NNP Loke/NNP Yuen/NNP Yow/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Hashim
# Ismail
# Ledang
#
# NLTK NER:
# (PERSON Hashim/NNP Ismail/NNP)
# (PERSON Ledang/NN)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Loke
#
# NLTK NER:
# (PERSON Siang/NN)
# (PERSON Tanjung/NNP)
# (PERSON Loke/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Bakili
# Muluzi
#
# NLTK NER:
# (PERSON Bakili/NNP Muluzi/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Eric
# Kumitsonyo
# Felix
# Mchami
# Muluzi
# Kamuzu
# Banda
#
# NLTK NER:
# (PERSON Blantyre/NNP)
# (PERSON Eric/NNP Kumitsonyo/NNP)
# (PERSON Felix/NNP Mchami/NNP)
# (PERSON Muluzi/NNP)
# (PERSON Kamuzu/NNP Banda/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kumitsonyo
#
# NLTK NER:
# (PERSON Kumitsonyo/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kumitsonyo
#
# NLTK NER:
# (PERSON Kumitsonyo/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Mchami
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Muluzi
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Peter
# Chin
# Fah
# Kui
#
# NLTK NER:
# (PERSON Peter/NNP Chin/NNP Fah/NNP Kui/NNP)
# (PERSON Pahang/NNP)
# (PERSON Johor/NNP)
# (PERSON Kuala/NNP Lumpur/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON States/NNPS)
# ------------------------------
#
# StanfordNLP NER:
# Datuk
# Mahbud
# Hashim
#
# NLTK NER:
# (PERSON Datuk/NNP Mahbud/NNP Hashim/NNP)
# (PERSON Sabak/NNP Bernam/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Denmark/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Asbjoern
# Jensen
#
# NLTK NER:
# (PERSON Asbjoern/NNP Jensen/NNP)
# ...
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dion
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Clapton
#
# NLTK NER:
# (PERSON Clapton/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Werner
# Herzog
#
# NLTK NER:
# (PERSON Werner/NNP Herzog/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Dieter
# Dengler
#
# NLTK NER:
# (PERSON Dieter/NNP Dengler/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Herzog
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dengler
# Herzog
#
# NLTK NER:
# (PERSON Dengler/NNP)
# (PERSON Herzog/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Dieter
#
# NLTK NER:
# (PERSON Dieter/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Herzog
# Dengler
#
# NLTK NER:
# (PERSON Herzog/NNP)
# (PERSON Dengler/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Dengler
#
# NLTK NER:
# (PERSON Dengler/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Herzog
# Dengler
#
# NLTK NER:
# (PERSON Herzog/NNP)
# (PERSON Dengler/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Dengler
#
# NLTK NER:
# (PERSON Dengler/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Herzog
#
# NLTK NER:
# (PERSON Herzog/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Werner
# Herzog
# Peter
# Zeitlinger
# Rainer
# Standke
# Glen
# Scantlebury
# Joe
# Bini
#
# NLTK NER:
# (PERSON Werner/NNP Herzog/NNP)
# (PERSON Peter/NNP Zeitlinger/NNP)
# (PERSON Rainer/NNP Standke/NNP)
# (PERSON Glen/NNP Scantlebury/NNP)
# (PERSON Joe/NNP Bini/NNP)
# (PERSON Werner/NNP Herzog/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Werner
# Herzog
# Dieter
# Dengler
#
# NLTK NER:
# (PERSON Werner/NNP Herzog/NNP)
# (PERSON Dieter/NNP Dengler/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Boris
# Yeltsin
#
# NLTK NER:
# (PERSON Boris/NNP Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Catherine
# Hall
#
# NLTK NER:
# (PERSON Catherine/NNP Hall/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Sergei
# Kiriyenko
# Yeltsin
#
# NLTK NER:
# (PERSON Sergei/NNP Kiriyenko/NNP)
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
# Kiriyenko
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Yevgeny
# Volk
#
# NLTK NER:
# (PERSON Yevgeny/NNP Volk/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Volk
# Yeltsin
# Kiriyenko
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
# Yeltsin
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Gennadi
# Zyuganov
# Kiriyenko
#
# NLTK NER:
# (PERSON Gennadi/NNP Zyuganov/NNP)
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Zyuganov
#
# NLTK NER:
# (PERSON Zyuganov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Vladimir
# Zhirinovsky
# Kiriyenko
# Yeltsin
#
# NLTK NER:
# (PERSON Vladimir/NNP)
# (PERSON Kiriyenko/NNP)
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Alexander
# Shokhin
# Viktor
# Chernomyrdin
# Yeltsin
#
# NLTK NER:
# (PERSON Alexander/NNP Shokhin/NNP)
# (PERSON Viktor/NNP Chernomyrdin/NNP)
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Grigory
# Yavlinsky
# Kiriyenko
#
# NLTK NER:
# (PERSON Grigory/NNP Yavlinsky/NNP)
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
# Yegor
# Stroyev
# Yuri
# Luzhkov
# Kiriyenko
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# (PERSON Yegor/NNP Stroyev/NNP)
# (PERSON Yuri/NNP Luzhkov/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
# Kiriyenko
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# (PERSON Kiriyenko/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Kiriyenko
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Yeltsin
# Kiriyenko
# Yeltsin
#
# NLTK NER:
# (PERSON Yeltsin/NNP)
# (PERSON Kiriyenko/NNP)
# (PERSON Yeltsin/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Eppie
# Lederer
#
# NLTK NER:
# (PERSON Eppie/NNP Lederer/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ann
# Landers
# Eppie
# Lederer
#
# NLTK NER:
# (PERSON Ann/NNP Landers/NNP)
# (PERSON Eppie/NNP Lederer/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Eppie
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Clinton
#
# NLTK NER:
# (PERSON Lake/NNP Michigan/NNP)
# (PERSON Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ronald
# Reagan
# Jimmy
# Carter
# Bill
# Clinton
#
# NLTK NER:
# (PERSON Ronald/NNP Reagan/NNP)
# (PERSON Jimmy/NNP Carter/NNP)
# (PERSON Bill/NNP Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Eppie
# Truman
# Bess
#
# NLTK NER:
# (PERSON Eppie/NNP)
# (PERSON Truman/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Clinton
#
# NLTK NER:
# (PERSON Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Clinton
#
# NLTK NER:
# (PERSON Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Tyler
#
# NLTK NER:
# (PERSON Des/NNP Moines/NNP)
# (PERSON Tyler/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Paula
# Jones
#
# NLTK NER:
# (PERSON Paula/NNP)
# (PERSON Jones/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Monica
# Lewinsky
#
# NLTK NER:
# (PERSON Monica/NNP)
# (PERSON Lewinsky/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Kenneth
# Starr
#
# NLTK NER:
# (PERSON Kenneth/NNP)
# (PERSON Starr/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Pepperdine/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Linda
# Tripp
#
# NLTK NER:
# (PERSON Linda/NNP)
# (PERSON Tripp/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Linda
# Tripp
#
# NLTK NER:
# (PERSON Linda/NNP Tripp/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Clinton
#
# NLTK NER:
# (PERSON Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Eppie
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Eppie
#
# NLTK NER:
# (PERSON Eppie/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Eppie
#
# NLTK NER:
# (PERSON Eppie/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Abe
# Friedman
#
# NLTK NER:
# (PERSON Abe/NNP Friedman/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Pauline
#
# NLTK NER:
# (PERSON Pauline/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Clinton
#
# NLTK NER:
# (PERSON Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Eppie
#
# NLTK NER:
# (PERSON Eppie/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Linda
# Tripp
#
# NLTK NER:
# (PERSON Linda/NNP Tripp/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Linda
# Tripp
#
# NLTK NER:
# (PERSON Linda/NNP Tripp/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Bill
# Clinton
#
# NLTK NER:
# (PERSON Bill/NNP Clinton/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Eppie
#
# NLTK NER:
# (PERSON Eppie/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Roslyn
# A.
# Walker
#
# NLTK NER:
# (PERSON Roslyn/NNP A./NNP Walker/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Susan
# Vogel
#
# NLTK NER:
# (PERSON Buli/NNP Master/NNP)
# (PERSON Susan/NNP Vogel/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Walker
# Olowe
#
# NLTK NER:
# (PERSON Walker/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Olowe
#
# NLTK NER:
# (PERSON Olowe/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# William
# B.
# Fagg
# Walker
#
# NLTK NER:
# (PERSON William/NNP B./NNP Fagg/NNP)
# (PERSON Walker/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Olowe
#
# NLTK NER:
# (PERSON Olowe/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ambrose
#
# NLTK NER:
# (PERSON Captain/NNP Ambrose/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Ambrose
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Olowe
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Olowe
#
# NLTK NER:
# (PERSON Olowe/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Olowe
#
# NLTK NER:
# (PERSON Olowe/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Olowe/NN)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Olowe
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Alisa
# LaGamma
#
# NLTK NER:
# (PERSON Alisa/NNP LaGamma/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Areogun
# Olowe
#
# NLTK NER:
# (PERSON Areogun/NNP)
# (PERSON Olowe/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Olowe
# Areogun
#
# NLTK NER:
# (PERSON Olowe/NNP)
# (PERSON Areogun/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# (PERSON Areogun/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Fagbite
# Asamu
# Falola
# Edun
#
# NLTK NER:
# (PERSON Fagbite/NNP Asamu/NNP)
# (PERSON Falola/NNP Edun/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Falola
# Edun
#
# NLTK NER:
# (PERSON Falola/NNP Edun/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Olabiyi
# Babalola
# Yai
#
# NLTK NER:
# (PERSON Olabiyi/NNP Babalola/NNP Yai/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
# Lamidi
# Fakeye
#
# NLTK NER:
# (PERSON Lamidi/NNP Fakeye/NNP)
# ------------------------------
#
# StanfordNLP NER:
# Jose
# Bedia
# Arturo
# Lindsay
# Manuel
# Vega
#
# NLTK NER:
# (PERSON Jose/NNP Bedia/NNP)
# (PERSON Arturo/NNP Lindsay/NNP)
# (PERSON Manuel/NNP Vega/NNP)
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
#
# StanfordNLP NER:
#
# NLTK NER:
# ------------------------------
