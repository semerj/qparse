# %%
import sqlite3
import nltk
import re
from collections import Counter
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk import RegexpParser
import nltk.chunk
import itertools
from nltk.tokenize import sent_tokenize
import nltk.text
from functools import partial

# %%
conn = sqlite3.connect('quotex')
c = conn.cursor()

# %%
tables = c.execute("SELECT name FROM sqlite_master WHERE type='table';")
for t in tables:
    print t
# Out:
# (u'auth_permission',)
# (u'auth_group_permissions',)
# (u'auth_group',)
# (u'auth_user_user_permissions',)
# (u'auth_user_groups',)
# (u'auth_user',)
# (u'django_content_type',)
# (u'django_session',)
# (u'django_site',)
# (u'django_admin_log',)
# (u'content_story',)
# (u'content_paragraph_sources',)
# (u'content_paragraph',)
# (u'content_source',)

# %%
content_paragraph = c.execute("SELECT * FROM content_paragraph;")
sqlite_data = []
for c in content_paragraph:
    sqlite_data.append(c)

# %%
Counter([row[3] for row in sqlite_data])
# Out:
# Counter({0: 1335, 1: 578})

# %%
tagged_data = []
for k, v in enumerate(sqlite_data):
    if v[3] in [0, 1]:
        tagged_data.append(v)

# %%
#just grab the quoted lines, remove unicode stuff
qtlines = []
for t in tagged_data:
    if t[3] == 1:
        qtlines.append(t[2].encode('utf-8').strip())
qtlines2 = []
for q in qtlines:
    qtlines2.append(q.decode('ascii', 'ignore'))

# %%
stuff = []
sentences = []
words = []
counter = 0 
#need to put the results into a tuple so you can figure out how the sentences relate to a paragraph
for q in qtlines2:
    sents = sent_tokenize(q)
    sentitems = []
    for sent in sents:
     sentences.append(sent)
     words = words + word_tokenize(sent)
     sentitems.append(pos_tag(word_tokenize(sent)))
     stuff.append((counter, sentitems))
    counter = counter + 1
#for s in sentences:
  #  print "***"
   # print s

# %%
#

#chunker rule to rip the quote out
#just the quote
plainqt = 'QT: { (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>) }'
#everything in front of the quote plus the quote
qtbegin = 'QT: { <.*>+ (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>) }'
#everything after the quote
qtend = 'QT: { (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>)+ <.*>+ }'

#now try chinking- aka exclude patterns
#grab everything before or after the quote and then discard the quote
qtbeginstuff = '''QT: 
                    { <.*>+ (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>) }
                    }(<``>|<\'\'>)+ <.*>+ (<''>|<\'\'>){                    
                '''
qtendstuff = '''QT: 
                   { (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>)+ <.*>+ }
                   } (<``>|<\'\'>)+ <.*>+ (<''>|<\'\'>){  
             '''

#try to parse common patterns after a quote
#find the peep after a quote: ex: said Dick Chaney
qtendpeepsaidafter = '''QT: 
                       { (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>)+ <.*>+ }
                       }(<``>|<\'\'>)+ <.*>+ (<''>|<\'\'>){ 
                       {(<states>|<stated>|<said>|<expressed>|<told>|<exclaimed>|<announced><added>|<comment>)+}
                 '''

#get the easiest stuff first out of the start and end of the quotes...need to refine this more
peepsbeginqt = '''QT: 
                    { (<DT>?<RB>?)?<JJ|CD>*(<JJ|CD><,>)*(<NN.*>)+ <VB.*> <,>?  } 
               
                '''

peepsbeginqt = '''QT: 
                    { (<DT>?<RB>?)?<JJ|CD>*(<JJ|CD><,>)*(<NN.*>)+ <VB.*> <,>?  } 
               
                '''

#get all the possible noun phrases after the end quote. 
peepsendqt = '''QT: 
                    { (<DT>?<RB>?)?<JJ|CD>*(<JJ|CD><,>)*(<NN.*>)+ <,>?  } 
                '''


peeps = '''PEEP: { <said> (<NN.*><POS>)?<RB>?<JJ.*>*<NN.*|CD>+ } 
                    }<SAID>{
         '''

#chunk and parse, and then put the remaining words back to together
def chunktext(sentencelist, rule):
    peepsdict = []
    for item in sentencelist:
      for sent in item[1]:
            itemdict = []
            cp = nltk.RegexpParser(rule)
            tree = cp.parse(sent)
            for subtree in tree.subtrees():
                if subtree.label() == 'QT': 
                 words =  [word[0] for word in subtree]
                 words = " ".join(words)
                 itemdict.append(words)
            if len(itemdict) > 0:
                peep = (item[0], " ".join(itemdict)) 
                peepsdict.append(peep)
    peepsdict = list(set(peepsdict))
    return peepsdict

# %%
startqtpeeps = chunktext(stuff, qtendpeepsaidafter)

print startqtpeeps[:5]
#startqtpeeps = chunktext(stuff)
#then look for NNP verb
# Out:
# [(348, u'of the investigation .'), (250, u'he said .'), (140, u'said Gerry Shih , who was a reporter for The Bay Citizen from its launch until December , when he left to join Reuters as a technology reporter .'), (536, u'Fama said .'), (38, u'Fletcher said .')]

# %%
for s[0] in startqtpeeps:
     st = s[0]
     stuff = st.split(',')
     print stuff

# %%
     } <VB.*> {
                    } <,> {

# %%
#get named entities and titles out of a quote
def get_peeps_title(endpeeps):
    endpeeps_title = [ (peep[0], peep[1].split(',')) for peep in endpeeps]
    peeps_with_title  = [(peep[0], peep[1][0], peep[1][1]) if len(peep[1]) > 1 else (peep[0], peep[1][0]) for peep  in endpeeps_title ]
    return peeps_with_title

# %%
#get the stuff at the start and end of a quote
endqtpeeps = chunktext(stuff, qtendpeepsaidafter)
startqtpeeps = chunktext(stuff, qtbeginstuff)

# %%
#function to pull out NER types
def text2tree(text):
    chunks = \
        ne_chunk(
            pos_tag(
                word_tokenize(text)))
            #,
        #binary=True) # binary only enables one type, "NE"
    return chunks

def chunk2entity(chunk):
    return ' '.join(leaf[0] for leaf in chunk.leaves())

def tree2entities(tree):
    # set comprehension, what the fuck up!?
    entities = {
        chunk2entity(chunk)
        for chunk in tree
        if hasattr(chunk, 'node')
    }
    # yea!
    return entities

# %%
#startpeepspre = [(peep[0], [pos_tag(word_tokenize(peep[1]))]) for peep in startqtpeeps]
#startpeeps = chunktext(startpeepspre, peepsbeginqt)
endpeepspre = [(peep[0], [pos_tag(word_tokenize(peep[1]))]) for peep in endqtpeeps]
endpeeps = chunktext(endpeepspre, peepsendqt)      
#endpeepstitlepre = [(peep[0], [pos_tag(word_tokenize(peep[1]))]) for peep in endpeeps]
#endpeepstitle = chunktext(endpeepspre, titleendpeeps)     
endpeeps_title = get_peeps_title(endpeeps)

# %%
print endpeeps
# Out:
# [(6, u'DeAngelo'), (172, u'De La Fuente'), (231, u'Policarpio'), (61, u'Esposto a series questions Schiefen computer habits preference pornography'), (522, u'Don Neuwirth , program manager the Oakland Schoolyard Initiative , a partnership nonprofit groups the Oakland Unified School District , the local elementary school yard this summer'), (78, u'Knobel'), (387, u'Mark Latonero , director research the Annenberg Center Communication Leadership Policy'), (367, u'Eiko'), (532, u'David McGhee , chief executive the Association California Healthcare Districts'), (187, u'the form reads'), (470, u'a close friend Mirkarimi told The Bay Citizen'), (534, u'Dev Mahadevan , the district chief executive'), (536, u'Fama'), (496, u'Vredenburg'), (423, u'Lee'), (62, u'Weyl wanting the suspect'), (233, u'Oversier , comment the Chicago recall Bombardier bid'), (530, u'Judy Nadler , a senior fellow government ethics Santa Clara University Markkula Center Applied Ethics a former mayor the city Santa Clara'), (476, u'a ban career law enforcement'), (526, u'the developer son , lives Marin prefers modern architecture'), (336, u'Perryman'), (390, u'Kris Hunt , executive director the Contra Costa Taxpayers Association'), (499, u'intensive care dying wife'), (211, u'Tomikoa'), (452, u'Audrey adding the services home income'), (337, u'Harvey'), (472, u'former San Francisco Mayor Art Agnos an interview'), (455, u'some families ,'), (16, u'Bonnie Trinclisti'), (26, u'Katz'), (444, u'former mayor Palo Alto Peter Drekmeier'), (28, u'Mr. Winnicker'), (214, u'Clark'), (196, u'Bayard'), (497, u'Vredenburg'), (523, u'Arrington'), (210, u'reporters the home Friday afternoon'), (335, u'Wayne Perryman , leader the National Oceanic Atmospheric Administration cetacean health life history program the agency office La Jolla'), (15, u'Trinclisti'), (139, u'Schachter'), (501, u'Harvey , sobs'), (393, u'Doss'), (167, u'adding assessment anecdotal information , not numbers'), (72, u'Woo'), (0, u'saidCalifornia State Parks Foundationpresident Elizabeth Goldstein'), (180, u'Albertoli'), (555, u'Crane'), (175, u'Albertoli'), (433, u'Arntz'), (5, u'Overman'), (469, u'Donna Levitt , a division manager'), (58, u'Esposto citing research police records'), (34, u'Lee'), (88, u'a similar case , McCabe'), (406, u'Charlie Pappas , San Francisco Divinity Tree dispensary late last year a federal letter'), (450, u'Lee'), (265, u'Bob Kimsey , anentomology professor the University California , Davis , the fluorescent arthropods subspecies Xystocheir dissecta , a species the Bay Area'), (96, u'Robinson'), (380, u'online sex'), (384, u'Detective Vincent Repetto the special victims unit'), (513, u'Stiglich'), (59, u'Weyl'), (258, u'office.Mirkarimi a member the Board Supervisors wife'), (138, u'Schachter'), (35, u'saidRussell Hancock , the president CEO Joint Venture Silicon Valley , a research group businesses local governments'), (545, u'Oakley'), (369, u'Eiko'), (331, u'Shaw'), (27, u'Mr. Lee'), (327, u'Stiglichsaid'), (507, u'Lee a statement'), (275, u'Canny'), (64, u'Esposto'), (448, u'Lee'), (494, u'Natalie Reeder , the lead author the study spent two years different species frogs Kings Canyon National Park part a masters'), (574, u'the experience reading strangers feeds Facebook Twitter'), (54, u'Esposto'), (272, u'Lee'), (408, u'Shum Preston , a spokesman Harris'), (313, u'Upton the Monday afternoon news conference Gascn'), (41, u'windows Fuller'), (109, u'Klaas glancing the school multipurpose room , a makeshift command center today'), (552, u'Goodwin'), (101, u'Archipley'), (436, u'Bolton ACLU NLG'), (372, u'Black'), (525, u'Figg'), (126, u'Brian Kelley , The Bay Citizen interim CEO'), (544, u'Oakley'), (375, u'Linda Lye , a staff attorney the American Civil Liberties Union Northern California , protesters lawsuits Oakland UC Davis'), (38, u'Fletcher'), (330, u'Peter Cohen , co-director the Council Community Housing Organizations , lobbies behalf nonprofit housing developers'), (219 ...

# %%
for peep in endpeeps_title:
    if len(peep) == 2:
        print "*****just a peep*****"
        persontree = text2tree(peep[1])
        print persontree
    print '************person/title*****************'
    if len(peep) > 2:
        person = text2tree(peep[1])
        print person
        title = text2tree(peep[2])
        print title
        print '*********************************'
# Out:
# *****just a peep*****
# (S DeAngelo/NNP)
# ************person/title*****************
# *****just a peep*****
# (S (PERSON De/NNP) La/NNP Fuente/NNP)
# ************person/title*****************
# *****just a peep*****
# (S Policarpio/NNP)
# ************person/title*****************
# *****just a peep*****
# (S
#   (GPE Esposto/NNP)
#   a/DT
#   series/NN
#   questions/NNS
#   (PERSON Schiefen/NNP)
#   computer/NN
#   habits/NNS
#   preference/NN
#   pornography/NN)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Don/NNP) (ORGANIZATION Neuwirth/NNP))
# (S
#   program/NN
#   manager/NN
#   the/DT
#   (ORGANIZATION Oakland/NNP Schoolyard/NNP Initiative/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Knobel/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Mark/NNP) Latonero/NNP)
# (S
#   director/NN
#   research/NN
#   the/DT
#   (ORGANIZATION
#     Annenberg/NNP
#     Center/NNP
#     Communication/NNP
#     Leadership/NNP)
#   Policy/NNP)
# *********************************
# *****just a peep*****
# (S (GPE Eiko/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON David/NNP) (ORGANIZATION McGhee/NNP))
# (S
#   chief/NN
#   executive/NN
#   the/DT
#   (ORGANIZATION
#     Association/NNP
#     California/NNP
#     Healthcare/NNP
#     Districts/NNPS))
# *********************************
# *****just a peep*****
# (S the/DT form/NN reads/NNS)
# ************person/title*****************
# *****just a peep*****
# (S
#   a/DT
#   close/JJ
#   friend/NN
#   (PERSON Mirkarimi/NNP)
#   told/VBD
#   The/DT
#   (ORGANIZATION Bay/NNP Citizen/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Dev/NNP) (PERSON Mahadevan/NNP))
# (S the/DT district/NN chief/NN executive/NN)
# *********************************
# *****just a peep*****
# (S (GPE Fama/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Vredenburg/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Weyl/NNP) wanting/NN the/DT suspect/NN)
# ************person/title*****************
# ************person/title*****************
# (S (GPE Oversier/NNP))
# (S
#   comment/NN
#   the/DT
#   (GPE Chicago/NNP)
#   recall/NN
#   Bombardier/NNP
#   bid/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Judy/NNP) (PERSON Nadler/NNP))
# (S
#   a/DT
#   senior/JJ
#   fellow/NN
#   government/NN
#   ethics/NNS
#   (PERSON
#     Santa/NNP
#     Clara/NNP
#     University/NNP
#     Markkula/NNP
#     Center/NNP
#     Applied/NNP)
#   Ethics/NNP
#   a/DT
#   former/JJ
#   mayor/NN
#   the/DT
#   city/NN
#   (PERSON Santa/NNP Clara/NNP))
# *********************************
# *****just a peep*****
# (S a/DT ban/NN career/NN law/NN enforcement/NN)
# ************person/title*****************
# ************person/title*****************
# (S the/DT developer/NN son/NN)
# (S
#   lives/NNS
#   (PERSON Marin/NNP)
#   prefers/NNS
#   modern/VBP
#   architecture/NN)
# *********************************
# *****just a peep*****
# (S (PERSON Perryman/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Kris/NNP) (ORGANIZATION Hunt/NNP))
# (S
#   executive/NN
#   director/NN
#   the/DT
#   (ORGANIZATION Contra/NNP Costa/NNP)
#   Taxpayers/NNP
#   Association/NNP)
# *********************************
# *****just a peep*****
# (S intensive/JJ care/NN dying/VBG wife/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Tomikoa/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Audrey/NNP) adding/NN the/DT services/NNS home/NN income/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Harvey/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   former/JJ
#   (GPE San/NNP)
#   Francisco/NNP
#   Mayor/NNP
#   (PERSON Art/NNP Agnos/NNP)
#   an/DT
#   interview/NN)
# ************person/title*****************
# ************person/title*****************
# (S some/DT families/NNS)
# (S )
# *********************************
# *****just a peep*****
# (S (PERSON Bonnie/NNP) (ORGANIZATION Trinclisti/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Katz/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   former/JJ
#   mayor/NN
#   (PERSON Palo/NNP Alto/NNP Peter/NNP Drekmeier/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Mr./NNP) Winnicker/NNP)
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Clark/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Bayard/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Vredenburg/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Arrington/NNP))
# ************person/title*****************
# *****just a peep*****
# (S reporters/NNS the/DT home/NN Friday/NNP afternoon/NN)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Wayne/NNP) (PERSON Perryman/NNP))
# (S
#   leader/NN
#   the/DT
#   (ORGANIZATION
#     National/NNP
#     Oceanic/NNP
#     Atmospheric/NNP
#     Administration/NNP)
#   cetacean/NN
#   health/NN
#   life/NN
#   history/NN
#   program/NN
#   the/DT
#   agency/NN
#   office/NN
#   (PERSON La/NNP Jolla/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Trinclisti/NNP))
# ************person/title*****************
# *****just a peep*****
# (S Schachter/NNP)
# ************person/title*****************
# ************person/title*****************
# (S (GPE Harvey/NNP))
# (S sobs/NNS)
# *********************************
# *****just a peep*****
# (S (GPE Doss/NNP))
# ************person/title*****************
# ************person/title*****************
# (S adding/VBG assessment/NN anecdotal/NN information/NN)
# (S not/RB numbers/NNS)
# *********************************
# *****just a peep*****
# (S (GPE Woo/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   (ORGANIZATION saidCalifornia/NNP)
#   State/NNP
#   (PERSON
#     Parks/NNP
#     Foundationpresident/NNP
#     Elizabeth/NNP
#     Goldstein/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Albertoli/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Crane/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Albertoli/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Arntz/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Overman/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Donna/NNP) (PERSON Levitt/NNP))
# (S a/DT division/NN manager/NN)
# *********************************
# *****just a peep*****
# (S (GPE Esposto/NNP) citing/NN research/NN police/NNS records/NNS)
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# ************person/title*****************
# (S a/DT similar/JJ case/NN)
# (S (GPE McCabe/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Charlie/NNP) (PERSON Pappas/NNP))
# (S
#   (GPE San/NNP)
#   (PERSON Francisco/NNP Divinity/NNP Tree/NNP)
#   dispensary/NN
#   late/RB
#   last/JJ
#   year/NN
#   a/DT
#   federal/JJ
#   letter/NN)
# *********************************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Bob/NNP) (PERSON Kimsey/NNP))
# (S
#   anentomology/NN
#   professor/NN
#   the/DT
#   (ORGANIZATION University/NNP California/NNP))
# *********************************
# *****just a peep*****
# (S (PERSON Robinson/NNP))
# ************person/title*****************
# *****just a peep*****
# (S online/NN sex/NN)
# ************person/title*****************
# *****just a peep*****
# (S
#   Detective/JJ
#   (ORGANIZATION Vincent/NNP)
#   Repetto/NNP
#   the/DT
#   special/JJ
#   victims/NNS
#   unit/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Stiglich/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Weyl/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   office.Mirkarimi/NN
#   a/DT
#   member/NN
#   the/DT
#   (ORGANIZATION Board/NNP)
#   Supervisors/NNP
#   wife/NN)
# ************person/title*****************
# *****just a peep*****
# (S Schachter/NNP)
# ************person/title*****************
# ************person/title*****************
# (S (ORGANIZATION saidRussell/NNP Hancock/NNP))
# (S
#   the/DT
#   president/NN
#   (ORGANIZATION CEO/NNP Joint/NNP Venture/NNP Silicon/NNP Valley/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Oakley/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Eiko/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Shaw/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Mr./NNP) (PERSON Lee/NNP))
# ************person/title*****************
# *****just a peep*****
# (S Stiglichsaid/NNP)
# ************person/title*****************
# *****just a peep*****
# (S Lee/NNP a/DT statement/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Canny/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Esposto/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Natalie/NNP) Reeder/NNP)
# (S
#   the/DT
#   lead/NN
#   author/NN
#   the/DT
#   study/NN
#   spent/NN
#   two/CD
#   years/NNS
#   different/JJ
#   species/NNS
#   frogs/NNS
#   Kings/NNS
#   (PERSON Canyon/NNP National/NNP Park/NNP)
#   part/NN
#   a/DT
#   masters/NNS)
# *********************************
# *****just a peep*****
# (S
#   the/DT
#   experience/NN
#   reading/NN
#   strangers/NNS
#   feeds/VBZ
#   (PERSON Facebook/NNP Twitter/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Esposto/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Shum/NNP) Preston/NNP)
# (S a/DT spokesman/NN (PERSON Harris/NNP))
# *********************************
# *****just a peep*****
# (S
#   (GPE Upton/NNP)
#   the/DT
#   Monday/NNP
#   afternoon/NN
#   news/NN
#   conference/NN
#   (PERSON Gascn/NNP))
# ************person/title*****************
# *****just a peep*****
# (S windows/NNS (PERSON Fuller/NNP))
# ************person/title*****************
# ************person/title*****************
# (S
#   (GPE Klaas/NNP)
#   glancing/NN
#   the/DT
#   school/NN
#   multipurpose/NN
#   room/NN)
# (S a/DT makeshift/NN command/NN center/NN today/NN)
# *********************************
# *****just a peep*****
# (S (GPE Goodwin/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Archipley/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Bolton/NNP) (ORGANIZATION ACLU/NNP) NLG/NNP)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Black/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Figg/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (GPE Brian/JJ) (PERSON Kelley/NNP))
# (S The/DT (ORGANIZATION Bay/NNP Citizen/NNP) interim/JJ CEO/NNP)
# *********************************
# *****just a peep*****
# (S (GPE Oakley/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Linda/NNP) (ORGANIZATION Lye/NNP))
# (S
#   a/DT
#   staff/NN
#   attorney/NN
#   the/DT
#   (ORGANIZATION
#     American/NNP
#     Civil/NNP
#     Liberties/NNPS
#     Union/NNP
#     Northern/NNP
#     California/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Fletcher/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Peter/NNP) (PERSON Cohen/NNP))
# (S
#   co-director/NN
#   the/DT
#   (ORGANIZATION Council/NNP)
#   Community/NNP
#   Housing/NNP
#   Organizations/NNP)
# *********************************
# *****just a peep*****
# (S (GPE Rockwell/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   Assistant/JJ
#   (ORGANIZATION District/NN Attorney/NNP Sarah/NNP Hawkins/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Goodwin/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Jesse/NNP) (ORGANIZATION Choper/NNP))
# (S
#   a/DT
#   professor/NN
#   the/DT
#   university/NN
#   law/NN
#   school/NN
#   chairman/NN
#   the/DT
#   review/NN
#   board/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Enid/NNP) (PERSON Pearson/NNP))
# (S
#   a/DT
#   former/JJ
#   (ORGANIZATION City/NNP Council/NNP)
#   member/NN
#   opposes/NNS
#   the/DT
#   facility/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Stephanie/NNP) (ORGANIZATION Ong/NNP) Stillman/NNP)
# (S
#   a/DT
#   spokeswoman/NN
#   the/DT
#   (ORGANIZATION District/NNP Attorney/NNP)
#   Office/NNP)
# *********************************
# ************person/title*****************
# (S (PERSON Kristine/NNP) (PERSON Shaff/NNP))
# (S
#   a/DT
#   spokeswoman/NN
#   the/DT
#   (ORGANIZATION Oakland/NNP Public/NNP Works/NNPS Agency/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Linda/NNP) (ORGANIZATION Lye/NNP))
# (S
#   the/DT
#   staff/NN
#   attorney/NN
#   the/DT
#   (ORGANIZATION ACLU/NNP Northern/NNP California/NNP)
#   the/DT
#   letter/NN
#   (ORGANIZATION OPD/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Block/NNP) an/DT email/NN)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Sue/NNP) (ORGANIZATION Piper/NNP))
# (S the/DT spokeswoman/NN the/DT mayor/NN office/NN)
# *********************************
# ************person/title*****************
# (S Davis/NNP the/DT local/JJ newspaper/NN)
# (S the/DT (ORGANIZATION Vallejo/NNP) Times-Herald/NNP)
# *********************************
# *****just a peep*****
# (S Waggoner/NNP a/DT statement/NN)
# ************person/title*****************
# *****just a peep*****
# (S affordable/JJ housing/NN)
# ************person/title*****************
# *****just a peep*****
# (S the/DT court/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Costa/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Bobel/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Kriss/NNP) (ORGANIZATION Worthington/NNP))
# (S a/DT (ORGANIZATION City/NNP Council/NNP) member/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Gerry/NNP) (ORGANIZATION Shih/NNP))
# (S
#   a/DT
#   reporter/NN
#   The/DT
#   (ORGANIZATION Bay/NNP Citizen/NNP)
#   launch/NN
#   December/NNP)
# *********************************
# ************person/title*****************
# (S (GPE Greg/NNP) (ORGANIZATION Harper/NNP))
# (S the/DT (ORGANIZATION AC/NNP Transit/NNP) board/NN)
# *********************************
# *****just a peep*****
# (S )/NN Hellman/NNP a/DT press/NN release/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Bolton/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Jorge/NNP) (ORGANIZATION Costa/NNP))
# (S the/DT (ORGANIZATION Giants/NNPS) operations/NNS director/NN)
# *********************************
# *****just a peep*****
# (S Peeples/NNS)
# ************person/title*****************
# *****just a peep*****
# (S the/DT charges/NNS)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Rocco/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON William/NNP) (ORGANIZATION Chiat/NNP))
# (S
#   executive/NN
#   director/NN
#   the/DT
#   (GPE California/NNP)
#   Association/NNP
#   Local/NNP
#   (PERSON Agency/NNP Formation/NNP Commissions/NNP))
# *********************************
# *****just a peep*****
# (S (PERSON Michael/NNP Le/NNP) this/DT morning/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE European/JJ) fiction/NN eras/NNS)
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Lee/NNP) an/DT interview/NN)
# ************person/title*****************
# *****just a peep*****
# (S the/DT report/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Voigt/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Rick/NNP) Laubscher/NNP)
# (S president/NN (PERSON Market/NN Street/NNP Railway/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Wiener/NNP))
# ************person/title*****************
# ************person/title*****************
# (S Weber/NNP)
# (S the/DT founding/NN editor/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Robert/NNP) (PERSON Rosenthal/NNP))
# (S (ORGANIZATION CIR/NNP) executive/NN director/NN)
# *********************************
# *****just a peep*****
# (S (GPE Vredenburg/NNP))
# ************person/title*****************
# ************person/title*****************
# (S saidCarey/NNP Morishige/NNP)
# (S
#   (GPE Pacific/NNP)
#   (ORGANIZATION Islands/NNPS)
#   regional/JJ
#   coordinator/NN
#   (ORGANIZATION NOAA/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Dwight/NNP) Detter/NNP)
# (S
#   a/DT
#   (GPE Vietnam/NNP)
#   veteran/NN
#   specialist/NN
#   (PERSON Whole/NNP Foods/NNP)
#   supermarkets/NNS
#   focus/VBZ
#   new/JJ
#   vendors/NNS)
# *********************************
# *****just a peep*****
# (S (GPE Imseeh/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Hillary/NNP) (PERSON Ronen/NNP))
# (S (GPE Campos/NNS) chief/VBP staff/NN)
# *********************************
# *****just a peep*****
# (S (PERSON Montiel/NNP) (PERSON Rodriguez/NNP Spanish/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Boyd/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Esposto/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   the/DT
#   mayor/NN
#   an/DT
#   interview/NN
#   a/DT
#   goal/NN
#   legislation/NN
#   a/DT
#   tax/NN
#   break/NN
#   companies/NNS
#   (PERSON Airbnb/NNP))
# ************person/title*****************
# *****just a peep*****
# (S Roberts/NNS)
# ************person/title*****************
# *****just a peep*****
# (S investor-owned/JJ utilities/NNS these/DT types/NNS projects/NNS)
# ************person/title*****************
# ************person/title*****************
# (S (GPE Serena/NNP) (PERSON Clayton/NNP))
# (S
#   Executive/JJ
#   Director/NNP
#   the/DT
#   (GPE California/NNP)
#   (PERSON School/NNP Health/NNP Centers/NNP)
#   Association/NNP)
# *********************************
# *****just a peep*****
# (S (PERSON Lee/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Adachi/NNP) the/DT judge/NN ruling/NN)
# ************person/title*****************
# ************person/title*****************
# (S 22-year-old/JJ (PERSON Vanna/NNP Ruiz/NNP))
# (S (PERSON Morgan/NNP) (PERSON Hill/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Capitelli/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Rose/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Piper/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Aaron/NNP) (PERSON Peskin/NNP))
# (S
#   a/DT
#   former/JJ
#   (ORGANIZATION Board/NNP)
#   Supervisors/NNP
#   president/NN
#   now/RB
#   head/NN
#   the/DT
#   local/JJ
#   (ORGANIZATION Democratic/JJ Party/NNP))
# *********************************
# ************person/title*****************
# (S
#   council/NN
#   member/NN
#   (PERSON Ignacio/NNP De/NNP La/NNP Fuente/NNP))
# (S office/NN requests/NNS the/DT location/NN the/DT blocks/NNS)
# *********************************
# ************person/title*****************
# (S
#   the/DT
#   experience/NN
#   a/DT
#   few/JJ
#   feet/NN
#   friends/NNS
#   naked/VBD
#   bodies/NNS)
# (S 60/CD years/NNS)
# *********************************
# ************person/title*****************
# (S the/DT agreement/NN health/NN care/NN)
# (S jobs/NNS)
# *********************************
# *****just a peep*****
# (S (GPE Stiglich/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Sinclair/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (GPE Tejeda/NNP))
# (S two/CD sons/NNS)
# *********************************
# *****just a peep*****
# (S
#   Detective/JJ
#   (PERSON Jeremy/NNP Martinez/NNP)
#   the/DT
#   (ORGANIZATION San/NNP Jose/NNP)
#   Police/NNP
#   Human/NNP
#   Trafficking/NNP
#   Task/NNP
#   Force/NNP)
# ************person/title*****************
# ************person/title*****************
# (S
#   (PERSON Money/NN)
#   (ORGANIZATION Mart/NNP)
#   a/DT
#   recent/JJ
#   afternoon/NN)
# (S (PERSON Bank/NNP) (ORGANIZATION America/NNP))
# *********************************
# *****just a peep*****
# (S
#   (GPE San/NNP)
#   (PERSON Francisco/NNP Mayor/NNP Ed/NNP Lee/NNP)
#   a/DT
#   statement/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Fletcher/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (GPE Sinclair/NNP))
# (S the/DT founder/NN director/NN (PERSON Man/NNP Alive/NNP))
# *********************************
# ************person/title*****************
# (S
#   (GPE Oakland/NNP)
#   (ORGANIZATION City/NNP Council/NNP)
#   President/NNP
#   (PERSON Larry/NNP Reid/NNP))
# (S the/DT area/NN)
# *********************************
# *****just a peep*****
# (S (GPE Gascn/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Jennifer/NNP) (PERSON Dunlop/NNP Fletcher/NNP))
# (S the/DT exhibition/NN curator/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Dennis/NNP) (PERSON Robinson/NNP))
# (S
#   a/DT
#   formerly/RB
#   homeless/JJ
#   (ORGANIZATION Army/NNP)
#   veteran/NN
#   (PERSON Guilfoyle/NNP)
#   body/NN)
# *********************************
# *****just a peep*****
# (S the/DT author/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Clayton/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Mr./NNP) (ORGANIZATION Neuwirth/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   any/DT
#   Veterans/NNPS
#   (PERSON Affairs/NNP Medical/NNP Center/NNP)
#   extension/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Campos/NNS))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Peter/NNP) (PERSON Sussman/NNP))
# (S
#   a/DT
#   former/JJ
#   president/NN
#   the/DT
#   (LOCATION Northern/NNP California/NNP)
#   chapter/NN
#   the/DT
#   (ORGANIZATION Society/NNP Professional/NNP Journalists/NNPS)
#   First/NNP
#   Amendment/NNP
#   issues/NNS)
# *********************************
# ************person/title*****************
# (S (PERSON Kevin/NNP) (PERSON Stein/NNP))
# (S
#   associate/NN
#   director/NN
#   the/DT
#   (GPE California/NNP)
#   Reinvestment/NNP
#   Coalition/NNP)
# *********************************
# ************person/title*****************
# (S (PERSON Jonathan/NNP) Weber/NNP)
# (S
#   the/DT
#   site/NN
#   the/DT
#   (LOCATION West/NNP Coast/NNP)
#   bureau/NN
#   chief/NN
#   (ORGANIZATION Reuters/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Lani/NNP) a/DT goofy/NN smile/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Lemon/NNP))
# ************person/title*****************
# *****just a peep*****
# (S Sgt/NNP)
# ************person/title*****************
# ************person/title*****************
# (S (GPE Rojas/NNP))
# (S
#   (GPE Spanish/JJ)
#   Thursday/NNP
#   morning/NN
#   a/DT
#   patio/NN
#   moments/NNS
#   the/DT
#   building/VBG
#   a/DT
#   magnitude/NN
#   5.2/CD
#   aftershock/NN)
# *********************************
# ************person/title*****************
# (S (GPE Oakley/NNP))
# (S lives/NNS Berkeley/NNP the/DT city/NN six/CD years/NNS)
# *********************************
# *****just a peep*****
# (S (GPE Reiskin/NNP))
# ************person/title*****************
# *****just a peep*****
# (S 30-plus/CD years/NNS law/NN enforcement/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Fama/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   (GPE Walker/NN)
#   repeating/VBG
#   refrain/NN
#   an/DT
#   actor/NN
#   enunciation/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Gascn/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Cook/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Rebecca/NNP) (ORGANIZATION Katz/NNP))
# (S head/NN the/DT agency/NN)
# *********************************
# *****just a peep*****
# (S Weber/NNP)
# ************person/title*****************
# *****just a peep*****
# (S (GPE St./NNP) (ORGANIZATION Croix/NNP))
# ************person/title*****************
# *****just a peep*****
# (S a/DT lawsuit/NN the/DT city/NN the/DT police/NN department/NN)
# ************person/title*****************
# *****just a peep*****
# (S the/DT case/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Rosenthal/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Malcolm/NNP) (ORGANIZATION Fartze/NNP))
# (S
#   a/DT
#   resident/NN
#   the/DT
#   (ORGANIZATION Fairmeadow/NNP)
#   neighborhood/NN)
# *********************************
# *****just a peep*****
# (S (PERSON Elizabeth/NNP) (PERSON Stampe/NNP WalkSF/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   (GPE Public/JJ)
#   (ORGANIZATION Works/NNS)
#   manager/NN
#   (PERSON Brad/NNP Eggleston/NNP)
#   the/DT
#   (ORGANIZATION Finance/NNP Committee/NNP)
#   meeting/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Cook/NNP))
# ************person/title*****************
# *****just a peep*****
# (S the/DT date/NN (PERSON Hamilton/NNP) family/NN others/NNS)
# ************person/title*****************
# *****just a peep*****
# (S (PERSON City/NNP) (ORGANIZATION Lights/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Cynthia/NNP) (PERSON Arrington/NNP))
# (S
#   the/DT
#   (ORGANIZATION Sobrante/NNP Park/NNP)
#   Resident/NNP
#   Action/NNP
#   Council/NNP
#   the/DT
#   (ORGANIZATION Neighborhood/NNP)
#   Crime/NNP
#   Prevention/NNP
#   Council/NNP)
# *********************************
# ************person/title*****************
# (S (GPE Rusty/NNP) Harris-Bishop/NNP)
# (S
#   a/DT
#   superfund/NN
#   division/NN
#   liaison/NN
#   the/DT
#   (ORGANIZATION EPA/NNP))
# *********************************
# *****just a peep*****
# (S (PERSON Albertoli/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (GPE Esposto/NNP))
# (S work/NN computer/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Courtney/NNP) (PERSON Miller/NNP))
# (S a/DT spokeswoman/NN (PERSON Block/NNP))
# *********************************
# *****just a peep*****
# (S the/DT mayor/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Schivley/NNP) an/DT interview/NN)
# ************person/title*****************
# ************person/title*****************
# (S a/DT text/NN message/NN)
# (S colleagues/NNS)
# *********************************
# *****just a peep*****
# (S
#   (GPE Lee/NNP)
#   sober/NN
#   press/NN
#   conference/NN
#   5/CD
#   p.m./NN
#   Tuesday/NNP)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Oversier/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Scheer/NNP))
# ************person/title*****************
# *****just a peep*****
# (S surroundings/NNS)
# ************person/title*****************
# *****just a peep*****
# (S
#   one/CD
#   article/NN
#   (ORGANIZATION theJournal/NNP)
#   Agricultural/NNP
#   Food/NNP
#   Chemistryin/NNP)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Trinclisti/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Cook/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Peter/NNP) (PERSON Straus/NNP))
# (S (GPE Muni/NNP) service/NN planner/NN)
# *********************************
# *****just a peep*****
# (S finances/NNS)
# ************person/title*****************
# ************person/title*****************
# (S Lt./NNP (PERSON Jason/NNP Fox/NNP))
# (S supervises/NNS the/DT pair/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Stephen/NNP) (ORGANIZATION Omatta/NNP))
# (S a/DT third-grade/JJ teacher/NN Tracy/NNP a/DT career/NN change/NN)
# *********************************
# *****just a peep*****
# (S (GPE Martel/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Anna/NNP) (ORGANIZATION Halprin/NNP))
# (S
#   the/DT
#   dancer/NN
#   choreographer/NN
#   the/DT
#   (ORGANIZATION Dancer/NNP Workshop/NNP Divisadero/NNP)
#   Street/NNP)
# *********************************
# *****just a peep*****
# (S (GPE Clayton/NNP))
# ************person/title*****************
# *****just a peep*****
# (S council/NN member/NN (PERSON Rebecca/NNP Kaplan/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Heaton/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   Assistant/JJ
#   (ORGANIZATION District/NN Attorney/NNP Linda/NNP)
#   Allen/NNP
#   the/DT
#   public/NN
#   defender/NN
#   office/NN
#   a/DT
#   conflict/NN
#   interest/NN
#   brother/NN
#   the/DT
#   murder/NN
#   case/NN)
# ************person/title*****************
# ************person/title*****************
# (S (GPE Mirkarimi/NNP) charges/NNS five/CD days/NNS)
# (S (PERSON Francis/NNP) (PERSON Tsang/NNP))
# *********************************
# *****just a peep*****
# (S
#   (PERSON Martin/NNP)
#   attending/NN
#   the/DT
#   support/NN
#   group/NN
#   concerns/NNS
#   the/DT
#   future/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Weyl/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Ang/NNP))
# (S a/DT recent/JJ college/NN graduate/NN)
# *********************************
# ************person/title*****************
# (S (PERSON James/NNP) (PERSON Marcin/NNP))
# (S
#   professor/NN
#   pediatric/JJ
#   critical/JJ
#   care/NN
#   medicine/NN
#   director/NN
#   the/DT
#   (ORGANIZATION
#     UC/NNP
#     Davis/NNP
#     Health/NNP
#     System/NNP
#     Pediatric/NNP
#     Telemedicine/NNP)
#   Program/NNP)
# *********************************
# *****just a peep*****
# (S venture/NN capital/NN investments/NNS)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Hiroyuke/NNP) (ORGANIZATION Iseki/NNP))
# (S
#   an/DT
#   assistant/JJ
#   professor/NN
#   (ORGANIZATION University/NNP Maryland/NNP))
# *********************************
# *****just a peep*****
# (S (PERSON Albertoli/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Juan/NNP) (ORGANIZATION Sanchez/NNP))
# (S an/DT officer/NN checks/NNS the/DT contenders/NNS)
# *********************************
# ************person/title*****************
# (S (PERSON Anne/NNP) Stuhldreher/NNP)
# (S
#   a/DT
#   senior/JJ
#   policy/NN
#   fellow/NN
#   (GPE New/NNP America/NNP)
#   Foundation/NNP)
# *********************************
# *****just a peep*****
# (S (GPE Reiskin/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Rebecca/NNP) (ORGANIZATION Jeschke/NNP))
# (S
#   director/NN
#   media/NNS
#   relations/NNS
#   the/DT
#   (ORGANIZATION Electronic/NNP Frontier/NNP Foundation/NNP))
# *********************************
# ************person/title*****************
# (S
#   (PERSON Gilroy/NNP)
#   resident/VBD
#   (PERSON Jeannie/NNP McDevitt/NNP))
# (S )
# *********************************
# ************person/title*****************
# (S campaign/NN spokeswoman/NN)
# (S (PERSON Erica/NNP) (PERSON Fox/NNP))
# *********************************
# ************person/title*****************
# (S
#   read/NN
#   an/DT
#   introductory/NN
#   tribute/NN
#   (PERSON Stewart/NNP Brand/NNP))
# (S the/DT publisher/NN)
# *********************************
# ************person/title*****************
# (S (PERSON Jim/NNP) (PERSON Ewert/NNP))
# (S
#   general/JJ
#   counsel/NN
#   the/DT
#   (GPE California/NNP)
#   Newspaper/NNP
#   Publishers/NNP
#   Association/NNP)
# *********************************
# *****just a peep*****
# (S the/DT investigation/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Cowan/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Worth/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Margaret/NNP) (ORGANIZATION Taylor/NNP))
# (S
#   the/DT
#   former/JJ
#   director/NN
#   the/DT
#   (ORGANIZATION
#     San/NNP
#     Mateo/NNP
#     County/NNP
#     Health/NNP
#     Department/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Mirkarimi/NNP) office/NN)
# ************person/title*****************
# ************person/title*****************
# (S Bates/NNS)
# (S
#   the/DT
#   (ORGANIZATION Alameda/NNP)
#   district/NN
#   attorney/NN
#   office/NN)
# *********************************
# *****just a peep*****
# (S (GPE Martel/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Farrell/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Rosenthal/NNP))
# ************person/title*****************
# *****just a peep*****
# (S a/DT leaflet/NN the/DT mayor/NN office/NN reads/NNS)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Schiefen/NNP))
# ************person/title*****************
# *****just a peep*****
# (S
#   LandPaths/NNS
#   executive/VBP
#   director/NN
#   (PERSON Craig/NNP Anderson/NNP))
# ************person/title*****************
# ************person/title*****************
# (S the/DT moral/JJ authority/NN sheriff/NN)
# (S )
# *********************************
# ************person/title*****************
# (S (PERSON John/NNP) (PERSON Maltbie/NNP))
# (S county/NN manager/NN (PERSON San/NNP Mateo/NNP County/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Angie/NNP) (PERSON Murphy/NNP))
# (S a/DT regular/JJ Muni/NNP commuter/NN)
# *********************************
# *****just a peep*****
# (S (GPE Keighran/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Boyd/NNP))
# ************person/title*****************
# *****just a peep*****
# (S the/DT alliance/NN)
# ************person/title*****************
# *****just a peep*****
# (S
#   (PERSON Bob/NNP)
#   (PERSON Planthold/NNP SF/NNP Walks/NNP Rolls/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Warren/NNP) (ORGANIZATION Newsome/NNP))
# (S
#   a/DT
#   spokesman/NN
#   the/DT
#   only/JJ
#   site/NN
#   an/DT
#   inquiry/NN
#   The/DT
#   (ORGANIZATION Bay/NNP Citizen/NNP))
# *********************************
# *****just a peep*****
# (S the/DT report/NN reads/NNS)
# ************person/title*****************
# *****just a peep*****
# (S
#   (PERSON Foster/NNP)
#   (GPE City/NNP)
#   Mayor/NNP
#   (PERSON Art/NNP Kiesel/NNP)
#   November/NNP
#   the/DT
#   city/NN
#   council/NN
#   a/DT
#   6.4/CD
#   percent/NN
#   increase/NN
#   garbage/NN
#   rate/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Rojas/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Walker/NN) authoritative/VBD baritone/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Mirkarimi/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Oversier/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Canny/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Alex/NNP) (ORGANIZATION Briscoe/NNP))
# (S
#   (PERSON Director/NNP)
#   (PERSON Alameda/NNP County/NNP Health/NNP Care/NNP)
#   Services/NNPS
#   Agency/NNP)
# *********************************
# *****just a peep*****
# (S (GPE Oakley/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Talai/NNP))
# ************person/title*****************
# *****just a peep*****
# (S Detective/JJ Martinez/NNP)
# ************person/title*****************
# *****just a peep*****
# (S adding/VBG the/DT filing/NN Monday/NNP)
# ************person/title*****************
# ************person/title*****************
# (S visitors/NNS)
# (S
#   the/DT
#   size/NN
#   the/DT
#   water/NN
#   drops/NNS
#   data/NNS
#   the/DT
#   (ORGANIZATION National/NNP Oceanic/NNP Atmospheric/NNP)
#   Administration/NNP
#   the/DT
#   new/JJ
#   Exploratorium/NNP
#   surroundings/NNS)
# *********************************
# *****just a peep*****
# (S no/DT weapon/NN connection/NN the/DT deaths/NNS)
# ************person/title*****************
# *****just a peep*****
# (S steel/NN (GPE China/NNP) the/DT bridge/NN project/NN)
# ************person/title*****************
# ************person/title*****************
# (S 2/LS a.m./NNP Thursday/NNP night/NN)
# (S noises/NNS Ocean/VBP (PERSON Avenue/NNP) night/NN)
# *********************************
# *****just a peep*****
# (S Mirkarimi/NNP the/DT court/NN)
# ************person/title*****************
# *****just a peep*****
# (S
#   (PERSON Meehantold/NNP)
#   (ORGANIZATION reportersKristin/NNP Bender/NNP Thomas/NNP Peele/NNP))
# ************person/title*****************
# *****just a peep*****
# (S no/DT weapon/NN connection/NN the/DT deaths/NNS)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Phil/NNP) (PERSON Bobel/NNP))
# (S
#   (ORGANIZATION Interim/NNP)
#   (ORGANIZATION Assistant/NNP)
#   Director/NNP
#   (ORGANIZATION Public/NNP Works/NNPS Palo/NNP Alto/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Mary/NNP) Alice/NNP Thornton/NNP)
# (S
#   the/DT
#   President/NNP
#   the/DT
#   (ORGANIZATION League/NNP Women/NNP Voters/NNP Palo/NNP Alto/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Briscoe/NNP))
# ************person/title*****************
# ************person/title*****************
# (S whose/NN photos/NNS)
# (S phone/NN numbers/NNS)
# *********************************
# ************person/title*****************
# (S (PERSON Corey/NNP) (ORGANIZATION Cook/NNP))
# (S
#   a/DT
#   political/JJ
#   science/NN
#   professor/NN
#   the/DT
#   (ORGANIZATION University/NNP San/NNP Francisco/NNP))
# *********************************
# ************person/title*****************
# (S the/DT moral/JJ authority/NN sheriff/NN)
# (S )
# *********************************
# *****just a peep*****
# (S eyes/NNS the/DT round/NN the/DT board/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Reiskin/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Paul/NNP) Oversier/NNP)
# (S
#   assistant/NN
#   general/NN
#   manager/NN
#   operations/NNS
#   (ORGANIZATION BART/NNP))
# *********************************
# ************person/title*****************
# (S the/DT report/NN)
# (S (GPE Hamilton/NNP) the/DT facility/NN)
# *********************************
# ************person/title*****************
# (S a/DT teasing/NN tone/NN)
# (S Eiko/NNP the/DT many/JJ holes/NNS the/DT canvas/NNS)
# *********************************
# ************person/title*****************
# (S Beverly/RB (PERSON Upton/NNP))
# (S
#   executive/NN
#   director/NN
#   the/DT
#   (ORGANIZATION
#     San/NNP
#     Francisco/NNP
#     Domestic/NNP
#     Violence/NNP
#     Consortium/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Adachi/NNP) the/DT courtroom/NN)
# ************person/title*****************
# *****just a peep*****
# (S (GPE Kaplan/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Trinclisti/NNP))
# ************person/title*****************
# *****just a peep*****
# (S voice/NN emotion/NN)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Eddie/NNP) (ORGANIZATION Silva/NNP))
# (S )
# *********************************
# *****just a peep*****
# (S (GPE Sandoval/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Mike/NNP) (PERSON Murray/NNP))
# (S
#   director/NN
#   community/NN
#   outreach/NN
#   (PERSON Pet/NNP Food/NNP Express/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Clayton/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (PERSON John/NNP) (ORGANIZATION Largier/NNP))
# (S a/DT (ORGANIZATION University/NNP California/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Doug/NNP) Given/NNP)
# (S
#   a/DT
#   project/NN
#   manager/NN
#   the/DT
#   (GPE U.S./NNP)
#   Geological/NNP
#   Survey/NNP
#   earthquake/NN
#   monitoring/VBG
#   program/NN)
# *********************************
# ************person/title*****************
# (S
#   a/DT
#   new/JJ
#   exhibition/NN
#   (PERSON Fuller/NNP)
#   visionary/NN
#   ideas/NNS
#   influence/NN
#   the/DT
#   (ORGANIZATION Bay/NNP Area/NNP))
# (S
#   Friday/NNP
#   the/DT
#   (ORGANIZATION San/NNP Francisco/NNP Museum/NNP Modern/NNP Art/NNP))
# *********************************
# *****just a peep*****
# (S (GPE Montesano/NNP))
# ************person/title*****************
# ************person/title*****************
# (S campaign/NN sparking/VBG changes/NNS federal/JJ)
# (S state/NN local/JJ procurement/NN policies/NNS)
# *********************************
# *****just a peep*****
# (S the/DT same/JJ press/NN conference/NN)
# ************person/title*****************
# ************person/title*****************
# (S (PERSON Robert/NNP) (PERSON Rosenthal/NNP))
# (S (ORGANIZATION CIR/NNP) executive/NN director/NN)
# *********************************
# *****just a peep*****
# (S (GPE Eiko/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Fox/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (PERSON Cox/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Olmo/NNP))
# ************person/title*****************
# *****just a peep*****
# (S the/DT charges/NNS)
# ************person/title*****************
# ************person/title*****************
# (S Kelly/RB Manheimer/NNP)
# (S
#   (ORGANIZATION EPA/NNP)
#   site/VBD
#   manager/NN
#   the/DT
#   (ORGANIZATION Heckathorn/NNP Site/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Elisabeth/NNP) (ORGANIZATION Voigt/NNP))
# (S senior/JJ staff/NN attorney/NN (PERSON Public/NNP Advocates/NNP))
# *********************************
# *****just a peep*****
# (S
#   a/DT
#   legal/JJ
#   document/NN
#   Feb./NNP
#   (PERSON Alameda/NNP County/NNP Court/NNP California/NNP Watch/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Wolf/NNP))
# ************person/title*****************
# ************person/title*****************
# (S (GPE Reiskin/NNP))
# (S head/NN the/DT transportation/NN agency/NN)
# *********************************
# ************person/title*****************
# (S
#   (PERSON Tsang/NNP)
#   said.The/NNP
#   mayor/NN
#   an/DT
#   announcement/NN
#   aboutthe/NN
#   case/NN
#   Tuesday/NNP)
# (S (PERSON Tsang/NNP))
# *********************************
# ************person/title*****************
# (S (PERSON Christine/NNP) (ORGANIZATION Falvey/NNP))
# (S (GPE Lee/NNP) spokeswoman/NN)
# *********************************
# *****just a peep*****
# (S (GPE Clayton/NNP) the/DT (ORGANIZATION ACA/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Rockwell/NNP))
# ************person/title*****************
# *****just a peep*****
# (S Commissioner/NNP (PERSON Dwight/NNP Meadows/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Simon/NNP))
# ************person/title*****************
# *****just a peep*****
# (S (GPE Meshad/NNP))
# ************person/title*****************

# %%
chunks = text2tree( endpeeps_title[2]
# Out:
# [(6, [u'DeAngelo']),
#  (172, [u'De La Fuente']),
#  (231, [u'Policarpio']),
#  (61,
#   [u'Esposto a series questions Schiefen computer habits preference pornography']),
#  (522,
#   [u'Don Neuwirth ',
#    u' program manager the Oakland Schoolyard Initiative ',
#    u' a partnership nonprofit groups the Oakland Unified School District ',
#    u' the local elementary school yard this summer']),
#  (78, [u'Knobel']),
#  (387,
#   [u'Mark Latonero ',
#    u' director research the Annenberg Center Communication Leadership Policy']),
#  (367, [u'Eiko']),
#  (532,
#   [u'David McGhee ',
#    u' chief executive the Association California Healthcare Districts']),
#  (187, [u'the form reads']),
#  (470, [u'a close friend Mirkarimi told The Bay Citizen']),
#  (534, [u'Dev Mahadevan ', u' the district chief executive']),
#  (536, [u'Fama']),
#  (496, [u'Vredenburg']),
#  (423, [u'Lee']),
#  (62, [u'Weyl wanting the suspect']),
#  (233, [u'Oversier ', u' comment the Chicago recall Bombardier bid']),
#  (530,
#   [u'Judy Nadler ',
#    u' a senior fellow government ethics Santa Clara University Markkula Center Applied Ethics a former mayor the city Santa Clara']),
#  (476, [u'a ban career law enforcement']),
#  (526, [u'the developer son ', u' lives Marin prefers modern architecture']),
#  (336, [u'Perryman']),
#  (390,
#   [u'Kris Hunt ',
#    u' executive director the Contra Costa Taxpayers Association']),
#  (499, [u'intensive care dying wife']),
#  (211, [u'Tomikoa']),
#  (452, [u'Audrey adding the services home income']),
#  (337, [u'Harvey']),
#  (472, [u'former San Francisco Mayor Art Agnos an interview']),
#  (455, [u'some families ', u'']),
#  (16, [u'Bonnie Trinclisti']),
#  (26, [u'Katz']),
#  (444, [u'former mayor Palo Alto Peter Drekmeier']),
#  (28, [u'Mr. Winnicker']),
#  (214, [u'Clark']),
#  (196, [u'Bayard']),
#  (497, [u'Vredenburg']),
#  (523, [u'Arrington']),
#  (210, [u'reporters the home Friday afternoon']),
#  (335,
#   [u'Wayne Perryman ',
#    u' leader the National Oceanic Atmospheric Administration cetacean health life history program the agency office La Jolla']),
#  (15, [u'Trinclisti']),
#  (139, [u'Schachter']),
#  (501, [u'Harvey ', u' sobs']),
#  (393, [u'Doss']),
#  (167, [u'adding assessment anecdotal information ', u' not numbers']),
#  (72, [u'Woo']),
#  (0, [u'saidCalifornia State Parks Foundationpresident Elizabeth Goldstein']),
#  (180, [u'Albertoli']),
#  (555, [u'Crane']),
#  (175, [u'Albertoli']),
#  (433, [u'Arntz']),
#  (5, [u'Overman']),
#  (469, [u'Donna Levitt ', u' a division manager']),
#  (58, [u'Esposto citing research police records']),
#  (34, [u'Lee']),
#  (88, [u'a similar case ', u' McCabe']),
#  (406,
#   [u'Charlie Pappas ',
#    u' San Francisco Divinity Tree dispensary late last year a federal letter']),
#  (450, [u'Lee']),
#  (265,
#   [u'Bob Kimsey ',
#    u' anentomology professor the University California ',
#    u' Davis ',
#    u' the fluorescent arthropods subspecies Xystocheir dissecta ',
#    u' a species the Bay Area']),
#  (96, [u'Robinson']),
#  (380, [u'online sex']),
#  (384, [u'Detective Vincent Repetto the special victims unit']),
#  (513, [u'Stiglich']),
#  (59, [u'Weyl']),
#  (258, [u'office.Mirkarimi a member the Board Supervisors wife']),
#  (138, [u'Schachter']),
#  (35,
#   [u'saidRussell Hancock ',
#    u' the president CEO Joint Venture Silicon Valley ',
#    u' a research group businesses local governments']),
#  (545, [u'Oakley']),
#  (369, [u'Eiko']),
#  (331, [u'Shaw']),
#  (27, [u'Mr. Lee']),
#  (327, [u'Stiglichsaid']),
#  (507, [u'Lee a statement']),
#  (275, [u'Canny']),
#  (64, [u'Esposto']),
#  (448, [u'Lee']),
#  (494,
#   [u'Natalie Reeder ',
#    u' the lead author the study spent two years different species frogs Kings Canyon National Park part a masters']),
#  (574, [u'the experience reading strangers feeds Facebook Twitter']),
#  (54, [u'Esposto']),
#  (272, [u'Lee']),
#  (408, [u'Shum Preston ', u' a spokesman Harris']),
#  (313, [u'Upton the Monday afternoon news conference Gascn']),
#  (41, [u'windows Fuller']),
#  (109,
#   [u'Klaas glancing the school multipurpose room ',
#    u' a makeshift command center today']),
#  (552, [u'Goodwin']),
#  (101, [u'Archipley']),
#  (436, [u'Bolton ACLU NLG']),
#  (372, [u'Black']),
#  (525, [u'Figg']),
#  (126, [u'Brian Kelley ', u' The Bay Citizen interim CEO']),
#  (544, [u'Oakley']),
#  (375,
#   [u'Linda Lye ',
#    u' a staff attorney the American Civil Liberties Union Northern California ',
#    u' protesters lawsuits Oakland UC Davis']),
#  (38, [u'Fletcher']),
#  (330,
#   [u'Peter Cohen ',
#    u' co-director the Council Community Housing Organizations ',
#    u' lobbies behalf nonprofit housing developers']),
#  (219, [u'Rockwell']),
#  (498, [u'Assistant District Attorney Sarah Hawkins']),
#  (553, [u'Goodwin']),
#  (376,
#   [u'Jesse Choper ',
#    u' a professor the university law school chairman the review board']),
#  (442,
#   [u'Enid Pearson ', u' a former City Council member opposes the facility']),
#  (556,
#   [u'Stephanie Ong Stillman ',
#    u' a spokeswoman the District Attorney Office']),
#  (521,
#   [u'Kristine Shaff ', u' a spokeswoman the Oakland Public Works Agency']),
#  (435,
#   [u'Linda Lye ',
#    u' the staff attorney the ACLU Northern California the letter OPD']),
#  (561, [u'Block an email']),
#  (161, [u'Sue Piper ', u' the spokeswoman the mayor office']),
#  (422, [u'Davis the local newspaper ', u' the Vallejo Times-Herald']),
#  (122, [u'Waggoner a statement']),
#  (447, [u'affordable housing']),
#  (510, [u'the court']),
#  (93, [u'Costa']),
#  (286, [u'Bobel']),
#  (70, [u'Kriss Worthington ', u' a City Council member']),
#  (140,
#   [u'Gerry Shih ',
#    u' a reporter The Bay Citizen launch December ',
#    u' Reuters a technology reporter']),
#  (235, [u'Greg Harper ', u' the AC Transit board']),
#  (128, [u') Hellman a press release']),
#  (378, [u'Bolton']),
#  (451, [u'Lee']),
#  (91, [u'Jorge Costa ', u' the Giants operations director']),
#  (234, [u'Peeples']),
#  (123, [u'the charges']),
#  (550, [u'Rocco']),
#  (535,
#   [u'William Chiat ',
#    u' executive director the California Association Local Agency Formation Commissions ',
#    u' the state 58 commissions']),
#  (112, [u'Michael Le this morning']),
#  (573, [u'European fiction eras']),
#  (32, [u'Lee an interview']),
#  (245, [u'the report']),
#  (564, [u'Voigt']),
#  (20,
#   [u'Rick Laubscher ',
#    u' president Market Street Railway ',
#    u' a nonprofit group preserving Muni history']),
#  (441, [u'Wiener']),
#  (132, [u'Weber ', u' the founding editor']),
#  (125, [u'Robert Rosenthal ', u' CIR executive director']),
#  (495, [u'Vredenburg']),
#  (151,
#   [u'saidCarey Morishige ', u' Pacific Islands regional coordinator NOAA']),
#  (102,
#   [u'Dwight Detter ',
#    u' a Vietnam veteran specialist Whole Foods supermarkets focus new vendors']),
#  (205, [u'Imseeh']),
#  (468, [u'Hillary Ronen ', u' Campos chief staff']),
#  (237, [u'Montiel Rodriguez Spanish']),
#  (417, [u'Boyd']),
#  (52, [u'Esposto']),
#  (31,
#   [u'the mayor an interview a goal legislation a tax break companies Airbnb']),
#  (355, [u'Roberts']),
#  (517, [u'investor-owned utilities these types projects']),
#  (8,
#   [u'Serena Clayton ',
#    u' Executive Director the California School Health Centers Association']),
#  (426, [u'Lee']),
#  (74, [u'Adachi the judge ruling']),
#  (113, [u'22-year-old Vanna Ruiz ', u' Morgan Hill']),
#  (541, [u'Capitelli']),
#  (394, [u'Rose']),
#  (166, [u'Piper']),
#  (29,
#   [u'Aaron Peskin ',
#    u' a former Board Supervisors president now head the local Democratic Party']),
#  (162,
#   [u'council member Ignacio De La Fuente ',
#    u' office requests the location the blocks']),
#  (364, [u'the experience a few feet friends naked bodies ', u' 60 years']),
#  (83, [u'the agreement health care ', u' jobs ', u' taxpayers']),
#  (557, [u'Stiglich']),
#  (186, [u'Sinclair']),
#  (229, [u'Tejeda ', u' two sons ', u' Cesar Adolfo ', u' the plant']),
#  (379,
#   [u'Detective Jeremy Martinez the San Jose Police Human Trafficking Task Force']),
#  (349, [u'Money Mart a recent afternoon ', u' Bank America']),
#  (477, [u'San Francisco Mayor Ed Lee a statement']),
#  (42, [u'Fletcher']),
#  (185, [u'Sinclair ', u' the founder director Man Alive']),
#  (518, [u'Oakland City Council President Larry Reid ', u' the area']),
#  (481, [u'Gascn']),
#  (37, [u'Jennifer Dunlop Fletcher ', u' the exhibition curator']),
#  (190,
#   [u'Dennis Robinson ', u' a formerly homeless Army veteran Guilfoyle body']),
#  (517, [u'the author']),
#  (11, [u'Clayton']),
#  (524, [u'Mr. Neuwirth']),
#  (200, [u'any Veterans Affairs Medical Center extension']),
#  (46, [u'Campos']),
#  (543,
#   [u'Peter Sussman ',
#    u' a former president the Northern California chapter the Society Professional Journalists First Amendment issues']),
#  (411,
#   [u'Kevin Stein ',
#    u' associate director the California Reinvestment Coalition ',
#    u' a nonprofit advocacy group']),
#  (129, [u'Jonathan Weber ', u' the site the West Coast bureau chief Reuters']),
#  (218, [u'Lani a goofy smile']),
#  (559, [u'Lemon']),
#  (194, [u'Sgt']),
#  (241,
#   [u'Rojas ',
#    u' Spanish Thursday morning a patio moments the building a magnitude 5.2 aftershock']),
#  (539, [u'Oakley ', u' lives Berkeley the city six years']),
#  (47, [u'Reiskin']),
#  (263, [u'30-plus years law enforcement']),
#  (537, [u'Fama']),
#  (228, [u'Walker repeating refrain an actor enunciation']),
#  (318, [u'Gascn']),
#  (30, [u'Cook']),
#  (23, [u'Rebecca Katz ', u' head the agency']),
#  (133, [u'Weber']),
#  (253, [u'St. Croix']),
#  (398, [u'a lawsuit the city the police department']),
#  (558, [u'the case']),
#  (135, [u'Rosenthal']),
#  (284,
#   [u'Malcolm Fartze ',
#    u' a resident the Fairmeadow neighborhood ',
#    u' the same day']),
#  (505, [u'Elizabeth Stampe WalkSF']),
#  (282, [u'Public Works manager Brad Eggleston the Finance Committee meeting']),
#  (428, [u'Cook']),
#  (246, [u'the date Hamilton family others']),
#  (572, [u'City Lights']),
#  (520,
#   [u'Cynthia Arrington ',
#    u' the Sobrante Park Resident Action Council the Neighborhood Crime Prevention Council']),
#  (320, [u'Rusty Harris-Bishop ', u' a superfund division liaison the EPA']),
#  (174, [u'Albertoli']),
#  (51, [u'Esposto ', u' work computer ', u' a child pornographer three years']),
#  (560, [u'Courtney Miller ', u' a spokeswoman Block']),
#  (268, [u'the mayor']),
#  (421, [u'Schivley an interview']),
#  (127, [u'a text message ', u' colleagues']),
#  (268, [u'Lee sober press conference 5 p.m. Tuesday']),
#  (358, [u'Oversier']),
#  (437, [u'Scheer']),
#  (115, [u'surroundings']),
#  (319, [u'one article theJournal Agricultural Food Chemistryin']),
#  (13, [u'Trinclisti']),
#  (429, [u'Cook']),
#  (18, [u'Peter Straus ', u' Muni service planner']),
#  (130, [u'finances']),
#  (50, [u'Lt. Jason Fox ', u' supervises the pair']),
#  (207, [u'Stephen Omatta ', u' a third-grade teacher Tracy a career change']),
#  (400, [u'Martel']),
#  (362,
#   [u'Anna Halprin ',
#    u' the dancer choreographer the Dancer Workshop Divisadero Street']),
#  (12, [u'Clayton']),
#  (163, [u'council member Rebecca Kaplan']),
#  (240, [u'Heaton']),
#  (87,
#   [u'Assistant District Attorney Linda Allen the public defender office a conflict interest brother the murder case']),
#  (269,
#   [u'Mirkarimi charges five days ',
#    u' Francis Tsang ',
#    u' a mayoral spokesman ',
#    u' a statement']),
#  (454, [u'Martin attending the support group concerns the future']),
#  (57, [u'Weyl']),
#  (502, [u'Ang ', u' a recent college graduate']),
#  (146,
#   [u'James Marcin ',
#    u' professor pediatric critical care medicine director the UC Davis Health System Pediatric Telemedicine Program']),
#  (33, [u'venture capital investments']),
#  (554, [u'Hiroyuke Iseki ', u' an assistant professor University Maryland']),
#  (179, [u'Albertoli']),
#  (206, [u'Juan Sanchez ', u' an officer checks the contenders']),
#  (350,
#   [u'Anne Stuhldreher ',
#    u' a senior policy fellow New America Foundation ',
#    u' a nonprofit public policy organization']),
#  (45, [u'Reiskin']),
#  (385,
#   [u'Rebecca Jeschke ',
#    u' director media relations the Electronic Frontier Foundation']),
#  (114, [u'Gilroy resident Jeannie McDevitt ', u'']),
#  (425, [u'campaign spokeswoman ', u' Erica Fox']),
#  (39, [u'read an introductory tribute Stewart Brand ', u' the publisher']),
#  (71,
#   [u'Jim Ewert ',
#    u' general counsel the California Newspaper Publishers Association']),
#  (348, [u'the investigation']),
#  (407, [u'Cowan']),
#  (266, [u'Worth']),
#  (529,
#   [u'Margaret Taylor ',
#    u' the former director the San Mateo County Health Department']),
#  (254, [u'Mirkarimi office']),
#  (386, [u'Bates ', u' the Alameda district attorney office']),
#  (377, [u'Martel']),
#  (438, [u'Farrell']),
#  (131, [u'Rosenthal']),
#  (165, [u'a leaflet the mayor office reads']),
#  (63, [u'Schiefen']),
#  (3, [u'LandPaths executive director Craig Anderson']),
#  (326, [u'the moral authority sheriff ', u'']),
#  (538, [u'John Maltbie ', u' county manager San Mateo County']),
#  (19,
#   [u'Angie Murphy ',
#    u' a regular Muni commuter ',
#    u' a bus the rain the Financial District']),
#  (332, [u'Keighran']),
#  (418, [u'Boyd']),
#  (155, [u'the alliance']),
#  (503, [u'Bob Planthold SF Walks Rolls']),
#  (383,
#   [u'Warren Newsome ',
#    u' a spokesman the only site an inquiry The Bay Citizen']),
#  (515, [u'the report reads']),
#  (285,
#   [u'Foster City Mayor Art Kiesel November the city council a 6.4 percent increase garbage rate']),
#  (242, [u'Rojas']),
#  (227, [u'Walker authoritative baritone']),
#  (431, [u'Mirkarimi']),
#  (357, [u'Oversier']),
#  (277, [u'Canny']),
#  (7,
#   [u'Alex Briscoe ',
#    u' Director Alameda County Health Care Services Agency ',
#    u' Oakland schools a prime example that challenge']),
#  (547, [u'Oakley']),
#  (177, [u'Talai']),
#  (382, [u'Detective Martinez']),
#  (81, [u'adding the filing Monday']),
#  (220,
#   [u'visitors ',
#    u' the size the water drops data the National Oceanic Atmospheric Administration the new Exploratorium surroundings']),
#  (176, [u'no weapon connection the deaths']),
#  (154, [u'steel China the bridge project']),
#  (213, [u'2 a.m. Thursday night ', u' noises Ocean Avenue night']),
#  (509, [u'Mirkarimi the court']),
#  (540, [u'Meehantold reportersKristin Bender Thomas Peele']),
#  (181, [u'no weapon connection the deaths']),
#  (280,
#   [u'Phil Bobel ', u' Interim Assistant Director Public Works Palo Alto']),
#  (443,
#   [u'Mary Alice Thornton ',
#    u' the President the League Women Voters Palo Alto']),
#  (10, [u'Briscoe']),
#  (381, [u'whose photos ', u' phone numbers ', u' services prices profiles']),
#  (427,
#   [u'Corey Cook ',
#    u' a political science professor the University San Francisco']),
#  (307, [u'the moral authority sheriff ', u'']),
#  (223, [u'eyes the round the board']),
#  (44, [u'Reiskin']),
#  (232, [u'Paul Oversier ', u' assistant general manager operations BART']),
#  (244, [u'the report ', u' Hamilton the facility']),
#  (359, [u'a teasing tone ', u' Eiko the many holes the canvas']),
#  (188,
#   [u'Beverly Upton ',
#    u' executive director the San Francisco Domestic Violence Consortium']),
#  (73, [u'Adachi the courtroom']),
#  (346, [u'Kaplan']),
#  (14, [u'Trinclisti']),
#  (423, [u'voice emotion']),
#  (209, [u'Eddie Silva ', u'']),
#  (86, [u'Sandoval']),
#  (24, [u'Mike Murray ', u' director community outreach Pet Food Express']),
#  (9, [u'Clayton']),
#  (149,
#   [u'John Largier ',
#    u' a University California ',
#    u' Davis oceanographer.Scientists small electronic transmitters ',
#    u' trackers ',
#    u' the tsunami']),
#  (238,
#   [u'Doug Given ',
#    u' a project manager the U.S. Geological Survey earthquake monitoring program']),
#  (37,
#   [u'a new exhibition Fuller visionary ideas influence the Bay Area ',
#    u' Friday the San Francisco Museum Modern Art']),
#  (416, [u'Montesano']),
#  (156,
#   [u'campaign sparking changes federal ',
#    u' state local procurement policies']),
#  (168, [u'the same press conference']),
#  (77, [u'Robert Rosenthal ', u' CIR executive director']),
#  (361, [u'Eiko']),
#  (60, [u'Fox']),
#  (516, [u'Cox']),
#  (89, [u'Olmo']),
#  (259, [u'the charges']),
#  (321, [u'Kelly Manheimer ', u' EPA site manager the Heckathorn Site']),
#  (563,
#   [u'Elisabeth Voigt ',
#    u' senior staff attorney Public Advocates ',
#    u' a civil rights organization San Francisco']),
#  (388, [u'a legal document Feb. Alameda County Court California Watch']),
#  (402, [u'Wolf']),
#  (21, [u'Reiskin ', u' head the transportation agency']),
#  (299,
#   [u'Tsang said.The mayor an announcement aboutthe case Tuesday ', u' Tsang']),
#  (329, [u'Christine Falvey ', u' Lee spokeswoman']),
#  (17, [u'Clayton the ACA']),
#  (220, [u'Rockwell']),
#  (392, [u'Commissioner Dwight Meadows']),
#  (144, [u'Simon']),
#  (198, [u'Meshad'])]

# %%
#Example of Cascaded chunking ---> this could be very useful. 
grammar = r"""
NP: {<DT|JJ|NN.*>+} # Chunk sequences of DT, JJ, NN
PP: {<IN><NP>} # Chunk prepositions followed by NP
VP: {<VB.*><NP|PP|S>+$} # Chunk rightmost verbs and arguments/adjun
S: {<NP><VP>} # Chunk NP, VP
"""
cp = nltk.RegexpParser(grammar)
tagged_tokens = [("Mary", "NN"), ("saw", "VBD"), ("the", "DT"),
("sit", "VB"), ("on", "IN"), ("the", "DT"), ("mat", "NN")]
print cp.parse(tagged_tokens)
# Out:
# (S
#   (NP Mary/NN)
#   saw/VBD
#   (S (NP the/DT) (VP sit/VB (PP on/IN (NP the/DT mat/NN)))))

# %%
for rel in nltk.sem.extract_rels('ORG', 'LOC', doc, corpus='ieer', pattern = IN):
        print(nltk.sem.rtuple(rel))
