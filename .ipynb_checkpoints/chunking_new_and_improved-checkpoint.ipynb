# %% [markdown]
# **DataFrame Chunking for Quation Speakers

# %%
import sqlite3
import nltk
import re
from collections import Counter
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk import RegexpParser
import nltk.chunk
import itertools
from nltk.tokenize import sent_tokenize
import nltk.text
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('max_columns', 50)
from pandas.io import sql
import functools
import operator
from functools import partial
from nltk import ne_chunk, pos_tag, word_tokenize
from nltk import RegexpParser
import nltk.chunk
import itertools
from nltk.tokenize import sent_tokenize
import nltk.text
from functools import partial
from string import punctuation

# %%
conn = sqlite3.connect('quotex')
c = conn.cursor()

# %%
tables = c.execute("SELECT name FROM sqlite_master WHERE type='table';")
for t in tables:
    print t
# Out:
# (u'auth_permission',)
# (u'auth_group_permissions',)
# (u'auth_group',)
# (u'auth_user_user_permissions',)
# (u'auth_user_groups',)
# (u'auth_user',)
# (u'django_content_type',)
# (u'django_session',)
# (u'django_site',)
# (u'django_admin_log',)
# (u'content_story',)
# (u'content_paragraph_sources',)
# (u'content_paragraph',)
# (u'content_source',)

# %%
tagged_data = []
for k, v in enumerate(sqlite_data):
    if v[3] in [0, 1]:
        tagged_data.append(v)

# %%
content_paragraph = c.execute("SELECT * FROM content_paragraph;")
sqlite_data = []
for c in content_paragraph:
    sqlite_data.append(c)

# %%
Counter([row[3] for row in sqlite_data])
# Out:
# Counter({0: 1335, 1: 578})

# %%
#read the the db into a dataframe
query = "SELECT story_id, quote, text FROM content_paragraph where quote = 1;"
bqs = sql.read_frame(query, con=conn)

# %%
#tokenize the text by sentence 
def convert2sents(txt):
    stuff = []
    results = sent_tokenize(txt)
    return results
    

#tokenize by words and then apply pos
def convert2words(text):
    return pos_tag(word_tokenize(text))

# %%
bqs['sentences'] = bqs['text'].apply(convert2sents)

# %%
bqs['words'] = bqs['text'].apply(convert2words)

# %%
for row in df.T.iteritems():

# %%
##PARSE RULES:

#next pull out all the NNPS and NNs near said
person_said_rule = '''
         QT:
             { (<``>|<\'\'>)+  <.*>+ (<''>|<\'\'>)+ <.*>+ }
                 } (<``>|<\'\'>)+ <.*>+ (<''>|<\'\'>){  
            {  <VB>+  <DT>?<NNP>+<JJ.*>*<RB>? <JJ.*>*<NN.*|CD>* } 
       
            } <VB.*> {
        '''

# %%
df = bqs[bqs['said_sent'] ==  1]

# %%
def find_person(text):
    words = [ word[0] for word in text]
    if 'said' in words:
        return True
    

#function to chunk text based on a rule
def chunktext(text, rule):
    peepsdict = []
   # words = pos_tag(word_tokenize(text))
    itemdict = []
    cp = nltk.RegexpParser(rule)
    for sent in text:
        sent = pos_tag(word_tokenize(sent))
        saidqt = find_person(sent)
        if saidqt:
            tree = cp.parse(sent)
            for subtree in tree.subtrees():
                if subtree.label() == 'QT': 
                    words =  [word[0] for word in subtree]
                    words = " ".join(words)
                    #print words
                    return words

# %%
#flag all the paragraphs that contain said and then dump them into into main dataframe
bqs['said_sent'] = pd.DataFrame(bqs.text.str.contains('said+'))

# %%
results = []
said_story_ids = []
for row in df.T.iteritems():
  peep = chunktext(row[1]['sentences'], person_said_rule)
  if peep:
      results.append(peep)
  else:
     results.append('')
  pid = row[1]['story_id'] 
  said_story_ids.append(pid)

# %%
#now merge the data back into the dataframe.
said_stuff = np.array(zip(said_story_ids, results))
df_said_stuff = pd.DataFrame({'story_id':said_stuff[:,0],'said_speaker':said_stuff[:,1]})

# %%
#now nerge everything back to gether on story_id
bqs['said_speakers'] = df_said_stuff['said_speaker']

# %%
speakers = bqs[bqs['said_speakers'] !=  '']
print len(speakers)
# Out:
# 457

# %%
df_missing_qts = bqs[bqs['said_speakers'] ==  '']
df_missing_qts
print len(df_said_stuff)
# Out:
# 471

# %%
df_said_stuff
# Out:
#                                          said_speaker story_id
# 0   California State Parks Foundation president El...    13661
# 1                                                        13661
# 2     LandPaths ' executive director Craig Anderson .    13661
# 3                                                        13661
# 4                                             Overman    13662
# 5                                            DeAngelo    13662
# 6   Alex Briscoe , Director of Alameda County Heal...    13663
# 7   Serena Clayton , Executive Director of the Cal...    13663
# 8                                             Clayton    13663
# 9                                             Briscoe    13663
# 10                                            Clayton    13663
# 11                                            Clayton    13663
# 12                                       Trinclisti .    13663
# 13                                         Trinclisti    13663
# 14                                         Trinclisti    13663
# 15                                  Bonnie Trinclisti    13663
# 16                                            Clayton    13663
# 17                                   Peter Straus , a    13664
# 18           Angie Murphy , a regular Muni commuter ,    13664
# 19  Rick Laubscher , president of Market Street Ra...    13664
# 20   Ed Reiskin , head of the transportation agency .    13664
# 21                Rebecca Katz , head of the agency .    13666
# 22  Mike Murray , director of community outreach f...    13666
# 23                                               Katz    13666
# 24                                            Mr. Lee    13667
# 25                                      Mr. Winnicker    13667
# 26  Aaron Peskin , a former Board of Supervisors p...    13667
# 27                                               Cook    13667
# 28                                    which the mayor    13667
# 29                                                Lee    13667
# 30                  for venture capital investments .    13667
# 31                                                Lee    13667
# 32  Russell Hancock , the president and CEO of Joi...    13668
# 33                                                 he    13668
# 34  Jennifer Dunlop Fletcher , the exhibition 's c...    13669
# 35                                           Fletcher    13669
# 36                                                       13669
# 37                                   of automatically    13669
# 38                                           Fletcher    13669
# 39                                                 he    13669
# 40                                            Reiskin    13670
# 41                                            Reiskin    13670
# 42                                             Campos    13670
# 43                                            Reiskin    13670
# 44                                                       13670
# 45                                                 he    13670
# 46          Lt. Jason Fox , who supervises the pair .    13671
# 47                                          Esposto ,    13671
# 48                                            Esposto    13671
# 49                                                       13671
# 50                                                 he    13671
# 51                                                       13671
# 52                                                 he    13671
# 53                                               Weyl    13671
# 54                                            Esposto    13671
# 55                                               Weyl    13671
# 56                                                Fox    13671
# 57                                            Esposto    13671
# 58                                               Weyl    13671
# 59                                           Schiefen    13671
#                                                   ...      ...
#
# [471 rows x 2 columns]
